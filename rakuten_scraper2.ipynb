# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import re
import csv

# === 初期設定 ===
today = datetime.date.today().strftime("%Y-%m-%d")
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}
APPLICATION_ID = "1028443959571093347"
HITS_PER_PAGE = 30
MAX_PAGES = 100

# === ショップID抽出関数 ===
def get_shop_id(shop_url):
    pattern = r'^https://www\.rakuten\.(?:co\.jp|ne\.jp)/(?:gold/)?([^/]+)/?$'
    m = re.match(pattern, shop_url)
    return m.group(1) if m else None

# === info.htmlから会社名・電話番号抽出 ===
def get_company_info_from_info_page(shop_url):
    for base in ["https://www.rakuten.co.jp", "https://www.rakuten.ne.jp/gold"]:
        info_url = f"{base}/{get_shop_id(shop_url)}/info.html"
        print(f"🔍 アクセス中: {info_url}")
        try:
            r = requests.get(info_url, headers=HEADERS, timeout=15)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, 'html.parser')

            company_name = "Not Found"
            phone_number = "Not Found"

            dl_tag = soup.find("dl")
            if dl_tag:
                dt_tags = dl_tag.find_all("dt")
                for dt in dt_tags:
                    dt_text = dt.get_text(" ", strip=True)
                    if not dt_text:
                        continue
                    # 「株式会社」を含み、前後30文字までに限定（有限会社などは除外）
                    pattern = r'([\s\S]{0,30}株式会社[\s\S]{0,30})(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
                    match = re.search(pattern, dt_text)
                    if match:
                        company_name = match.group(1).strip()
                        break



            tel_elem = soup.find(text=re.compile("TEL:"))
            if tel_elem:
                match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
                if match:
                    phone_number = match.group(1)

            return company_name, phone_number
        except Exception:
            continue
    return "Not Found", "Not Found"

# === 商品検索API実行 ===
def get_product_urls_from_keyword(keyword, existing_shop_ids):
    print(f"🔍 キーワード: {keyword} から商品URLを取得中...")
    unique_shop_ids = set()
    item_urls = []

    for page in range(1, MAX_PAGES + 1):
        params = {
            'applicationId': APPLICATION_ID,
            'keyword': keyword,
            'format': 'json',
            'hits': HITS_PER_PAGE,
            'page': page
        }
        try:
            response = requests.get(
                'https://app.rakuten.co.jp/services/api/IchibaItem/Search/20220601',
                params=params,
                headers=HEADERS,
                timeout=10
            )
            response.raise_for_status()
            data = response.json()
            for item in data.get("Items", []):
                item_url = item["Item"]["itemUrl"]
                shop_id = item["Item"]["shopCode"]
                if shop_id not in existing_shop_ids and shop_id not in unique_shop_ids:
                    item_urls.append((item_url, shop_id))
                    unique_shop_ids.add(shop_id)
        except Exception as e:
            print(f"❌ 商品取得失敗: {e}")
            break
    print(f"✅ 商品URL取得数: {len(item_urls)}")
    return item_urls

# === 実行 ===
if __name__ == "__main__":
    existing_file = "rakuten_scraping.csv"
    existing_shop_ids = set()
    if os.path.exists(existing_file):
        with open(existing_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_id = get_shop_id(row.get("shop_url", ""))
                if shop_id:
                    existing_shop_ids.add(shop_id)
        print(f"📄 既存のショップID数: {len(existing_shop_ids)}")

    # urls.txt からキーワード取得
    with open("urls.txt", "r", encoding="utf-8") as f:
        keywords = [line.strip() for line in f if line.strip()]

    new_shops = []
    for kw in keywords:
        product_data = get_product_urls_from_keyword(kw, existing_shop_ids)
        for item_url, shop_id in product_data:
            shop_url = f"https://www.rakuten.co.jp/{shop_id}/"
            company_name, tel = get_company_info_from_info_page(shop_url)
            new_shops.append({
                "shop_url": shop_url,
                "info_url": shop_url.rstrip('/') + "/info.html",
                "company_name": company_name,
                "telephone": tel
            })
            existing_shop_ids.add(shop_id)
            time.sleep(random.uniform(1, 1.5))

    # 書き出し
    if new_shops:
        os.makedirs("csv_data", exist_ok=True)
        now = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        filename = f"csv_data/{now}_company_info.csv"
        with open(filename, "w", newline='', encoding="utf-8-sig") as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url", "info_url", "company_name", "telephone"])
            writer.writeheader()
            writer.writerows(new_shops)
        print(f"💾 出力完了: {filename}")

        # 既存リスト更新
        with open(existing_file, 'a', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            for row in new_shops:
                writer.writerow({"shop_url": row["shop_url"]})
        print(f"🆕 既存リストを更新しました（追加件数: {len(new_shops)}件）")
    else:
        print("⚠️ 新しいショップは見つかりませんでした。")
# Out:
# 📄 既存のショップID数: 8653
# 🔍 キーワード: 本革 カードケース レディース ギフト から商品URLを取得中...
# ✅ 商品URL取得数: 215
# 🔍 アクセス中: https://www.rakuten.co.jp/rockbeauty/info.html
# C:\Users\to0ar\AppData\Local\Temp\ipykernel_10508\3271105338.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tel_elem = soup.find(text=re.compile("TEL:"))
# 🔍 アクセス中: https://www.rakuten.co.jp/aru-mart/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/shuncorp/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sakura0001/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/foofoo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/aobax/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rplus-3/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/swingplus/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/gs-cafe/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/lifelivecmz/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/lobshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/takagami/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sunport125/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/osyarehime/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/graneu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/grav-online/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cielo-leather/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/zakafashion/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/pochashop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/haipule-success/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yilin/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/osharestore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/accessoriesshaku/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/annekor/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/priol/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kaimonotengoku/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/peacekoubou/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/enimuot/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/liview/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/style925/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/guna/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jsmileshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/belle0411/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/lauda/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/confianceshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/journey-free/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/peapod/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ltcm/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dores-smes/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/icaca/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/teria/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/diyshop-krara/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ok-maruken/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mitoyo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/imukat5884/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/origin-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rollwood/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/esl-shop2/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/plumhut8888/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/moringamirai/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/e-bagstores/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/luxsport/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/e-piglet/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cincshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/popostore2023/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sapolia/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/naruru/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/triplestar0124/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/icaca-duo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/topo-design/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dockii/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/glp001/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kurashinokoubin/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/xinye-osaka/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/tu-meme/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/melville/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ten-hy2023/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/changing-my-life/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/atfashion/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bestofbest/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hanaro-online-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cosmevivi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/toraberu888/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sixspace/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/blueplanet-colore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/pipi1012/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/laforest/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/easysmx/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hanaro/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/asahi-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/vivaland/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/zakka-haru/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/tapipanda00/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/leafdeer/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/romanshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bellbeplus/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/melody/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/plan-a/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/patri/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/krara-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yyds-qiuerqiang/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/youyouto/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mbk-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jellyfish16/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bubustore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mitumoto001/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/doudou2021/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-trinityworks/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hibifura/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/impossibledream/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nesleaf/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/asi-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rollincandy/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/watashinoheya/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/annekor22/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mucshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kanedayuhin/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kinbarashouten/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/p2factory/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/worldstore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/osstore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sun-sun/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/motto-motto/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/matthew-arche/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/zakkastoremoo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rinzo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kouso-seikatsu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/and--c/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ayjudie/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/r-and-m-s/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/recatino/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/akina/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/graphia-marks/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/leather-world/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cluar/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/luckpanda/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/evo-inc/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/arc-tokyo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/milkypop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/keitsu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cpaalliance/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/soyii/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kameto/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/zjshop2022/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/caselabo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/morigawa1019/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/lumeland/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/inujirou/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ulimalie/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/puick/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/opale/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/shogo01/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/pitch/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/shop-mirai-/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/handa-luana1023/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/polapola/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/casedou/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/eikoshop11/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fios-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ang-springs/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fancywonderland/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/allinstyle/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/calinou/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rock-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/geki-pla/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ko-yo-/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/stylise/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/e-me-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/haruco/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ttmix/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/littletown/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/tgmart/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/niuniu-shop2/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/niuniu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/myjourney/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/monoboxjapan/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/moltofelice/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kashiwa01/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/victolieve/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yorozuya33/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/congra/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/aguichant-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hiro-pro/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/exrevo-2/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/blossomyogurt/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/zaczac188/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/roundsheep/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/monos-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/plowinc/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/casesr/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/youko6699/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/msut/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ccpi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/artpiece/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/87-hana/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/gogoshopping/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/suzuki-international/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kumoshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/otakaratuuhann-ac/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/plusnao/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nekonote-kobo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/zodiac-aster/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dio-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/loof-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/casecore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-nihon-sweden/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sunsunkan/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bon-like/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/regian/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/milaibao/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/stravel/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nextore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kobe-s/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/futuraruru/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/newphilia/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/krara/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/anex2023/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/setasuta-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/unicona/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dream-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/outprize/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/seventh/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/linksonline/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/askrtech/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kokone111/info.html
# 💾 出力完了: csv_data/2025-04-10_company_info.csv
# 🆕 既存リストを更新しました（追加件数: 215件）
