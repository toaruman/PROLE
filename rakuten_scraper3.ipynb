# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import re
import csv

# === 初期設定 ===
today = datetime.date.today().strftime("%Y-%m-%d")
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}
APPLICATION_ID = ""
HITS_PER_PAGE = 30
MAX_PAGES = 100

# === ショップID抽出関数 ===
def get_shop_id(shop_url):
    pattern = r'^https://www\.rakuten\.(?:co\.jp|ne\.jp)/(?:gold/)?([^/]+)/?$'
    m = re.match(pattern, shop_url)
    return m.group(1) if m else None

# === info.htmlから会社名・電話番号抽出 ===
def get_company_info_from_info_page(shop_url):
    for base in ["https://www.rakuten.co.jp", "https://www.rakuten.ne.jp/gold"]:
        info_url = f"{base}/{get_shop_id(shop_url)}/info.html"
        print(f"🔍 アクセス中: {info_url}")
        try:
            r = requests.get(info_url, headers=HEADERS, timeout=15)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, 'html.parser')

            company_name = "Not Found"
            phone_number = "Not Found"

            dl_tag = soup.find("dl")
            if dl_tag:
                dt_tags = dl_tag.find_all("dt")
                for dt in dt_tags:
                    dt_text = dt.get_text(" ", strip=True)
                    if not dt_text:
                        continue
                    # 「株式会社」を含み、前後30文字までに限定（有限会社などは除外）
                    pattern = r'([\s\S]{0,30}株式会社[\s\S]{0,30})(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
                    match = re.search(pattern, dt_text)
                    if match:
                        company_name = match.group(1).strip()
                        break



            tel_elem = soup.find(text=re.compile("TEL:"))
            if tel_elem:
                match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
                if match:
                    phone_number = match.group(1)

            return company_name, phone_number
        except Exception:
            continue
    return "Not Found", "Not Found"

# === 商品検索API実行 ===
def get_product_urls_from_keyword(keyword, existing_shop_ids):
    print(f"🔍 キーワード: {keyword} から商品URLを取得中...")
    unique_shop_ids = set()
    item_urls = []

    for page in range(1, MAX_PAGES + 1):
        params = {
            'applicationId': APPLICATION_ID,
            'keyword': keyword,
            'format': 'json',
            'hits': HITS_PER_PAGE,
            'page': page
        }
        try:
            response = requests.get(
                'https://app.rakuten.co.jp/services/api/IchibaItem/Search/20220601',
                params=params,
                headers=HEADERS,
                timeout=10
            )
            response.raise_for_status()
            data = response.json()
            for item in data.get("Items", []):
                item_url = item["Item"]["itemUrl"]
                shop_id = item["Item"]["shopCode"]
                if shop_id not in existing_shop_ids and shop_id not in unique_shop_ids:
                    item_urls.append((item_url, shop_id))
                    unique_shop_ids.add(shop_id)
        except Exception as e:
            print(f"❌ 商品取得失敗: {e}")
            break
    print(f"✅ 商品URL取得数: {len(item_urls)}")
    return item_urls

# === 実行 ===
if __name__ == "__main__":
    existing_file = "rakuten_scraping.csv"
    existing_shop_ids = set()
    if os.path.exists(existing_file):
        with open(existing_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_id = get_shop_id(row.get("shop_url", ""))
                if shop_id:
                    existing_shop_ids.add(shop_id)
        print(f"📄 既存のショップID数: {len(existing_shop_ids)}")

    # urls.txt からキーワード取得
    with open("urls.txt", "r", encoding="utf-8") as f:
        keywords = [line.strip() for line in f if line.strip()]

    new_shops = []
    for kw in keywords:
        product_data = get_product_urls_from_keyword(kw, existing_shop_ids)
        for item_url, shop_id in product_data:
            shop_url = f"https://www.rakuten.co.jp/{shop_id}/"
            company_name, tel = get_company_info_from_info_page(shop_url)
            new_shops.append({
                "shop_url": shop_url,
                "info_url": shop_url.rstrip('/') + "/info.html",
                "company_name": company_name,
                "telephone": tel
            })
            existing_shop_ids.add(shop_id)
            time.sleep(random.uniform(1, 1.5))

    # 書き出し
    if new_shops:
        os.makedirs("csv_data", exist_ok=True)
        filename = f"csv_data/{today}_company_info.csv"
        with open(filename, "w", newline='', encoding="utf-8-sig") as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url", "info_url", "company_name", "telephone"])
            writer.writeheader()
            writer.writerows(new_shops)
        print(f"💾 出力完了: {filename}")

        # 既存リスト更新
        with open(existing_file, 'a', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            for row in new_shops:
                writer.writerow({"shop_url": row["shop_url"]})
        print(f"🆕 既存リストを更新しました（追加件数: {len(new_shops)}件）")
    else:
        print("⚠️ 新しいショップは見つかりませんでした。")
# Out:
# 📄 既存のショップID数: 8907
# 🔍 キーワード: レザージャケット から商品URLを取得中...
# ✅ 商品URL取得数: 89
# 🔍 アクセス中: https://www.rakuten.co.jp/soyous/info.html
# C:\Users\to0ar\AppData\Local\Temp\ipykernel_11780\3271105338.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tel_elem = soup.find(text=re.compile("TEL:"))
# 🔍 アクセス中: https://www.rakuten.co.jp/showcase/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cyoacyoa/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/askshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cliosi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mdkstorehome/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/moto-zoa/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jd-netwark/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/a-s-k/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/tujya666/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/whitepanther/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sperling/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/styleblockmen/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nature-tree14/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bijinshouji/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/thebridge/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ladies-wing/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hinosyopu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/toueishop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fukuuriyasan/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yamadasyouji/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/galgirls/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sheldon-ec/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/babyclothdoctor/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/akashihonpo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-arcade/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/shopya12/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/spillhope88/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/marche-iwai/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/shoeki-market/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dayforme/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/voxtrading/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/topstyleone/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/royal-pine/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/joonstore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hasukii/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/b-style/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/daisoleadershop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rbm-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fudanzukainoomise/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/tis3580/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sk-market/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/chittoshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/whitebang/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/funs2002/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/smileshop2525/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/asialoop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ichimaru10/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/cotton-kiss/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/snetwebshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dainese/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yuuwiwi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bikeseven/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/b-faith/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hakobune306288/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/neighbor111/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/barns-net2/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/satosishop888/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/speedfashion/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jline/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/firststep2/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/suzurann/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/baytradew/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/smilife0319/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/anytime0914/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/black-queen/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/r-columbus/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ysparts/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/workerbee88/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/anmichi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/wegostore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-f-shop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sumoa/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/babymon/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/toyogawa-netshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kokorohero/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/j-ambleshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fashionmens/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/webbymono/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/darjeeling/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/takedasatoshi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-nikkashop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fieldline/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jeytime/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/gluck-g/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yport/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/just-for-you001/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ponyriver/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/naked-platinum/info.html
# 🔍 キーワード: レザーキーケース から商品URLを取得中...
# ✅ 商品URL取得数: 169
# 🔍 アクセス中: https://www.rakuten.co.jp/yas-trading/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/oobikiyaking/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/onecarat/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/gzarea/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/taruba-0831/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sumahohonpo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp