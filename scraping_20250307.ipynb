# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import sys
import re
import csv

today = str(datetime.date.today())

class RakutenScraper:
    """
    楽天のカテゴリページや検索結果ページから再帰的にリンクを収集し、
    商品ページURLから「ショップURL」を抽出するサンプルクラス。
    できるだけ多くのショップURLを抽出します。
    """
    def __init__(self, base_url):
        self.base_url = base_url
        self.master_list = []        # 再帰的に収集したリンクを保存
        self.item_page_list = []     # 楽天の商品ページURLのみを格納
        self.shop_url_list = set()   # ショップURL（重複排除）を格納

    def simple_request(self, url, first=False):
        """
        指定URLのページから <a> タグの href を収集し、self.master_list に追加する。
        first=True のときは、取得したリンクリストを返す（初回のみ）。
        """
        print(f"アクセス中: {url} | 既存リンク数: {len(self.master_list)}")
        try:
            r = requests.get(url, timeout=(30.0, 47.5))
        except requests.exceptions.RequestException:
            return False

        if r.status_code == 200 and 'text/html' in r.headers.get('Content-Type', ''):
            soup = BeautifulSoup(r.content, 'html.parser')
            atag_list = soup.find_all('a')
            if first:
                unique_hrefs = []
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                    if href and (href not in unique_hrefs):
                        unique_hrefs.append(href)
                return unique_hrefs
            else:
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                return len(self.master_list)
        else:
            return False

    def get_item_url(self):
        """
        master_list に含まれるURLのうち、楽天の商品ページURLを抽出し、
        self.item_page_list を再計算する。
        例: https://item.rakuten.co.jp/ショップコード/商品ID/
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        self.item_page_list = []
        for url in self.master_list:
            if url and re.match(pattern, url):
                self.item_page_list.append(url)
        return self.item_page_list

    def extract_shop_urls(self):
        """
        item_page_list の各URLからショップコードを抜き出し、
        https://www.rakuten.co.jp/ショップコード/ の形でショップURLを生成します。
        リミットは設けず、可能な限り多くのショップURLを抽出します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        shop_urls = set()
        for item_url in self.item_page_list:
            m = re.match(pattern, item_url)
            if m:
                shop_code = m.group(1)
                shop_url = f"https://www.rakuten.co.jp/{shop_code}/"
                shop_urls.add(shop_url)
        self.shop_url_list = shop_urls
        return list(shop_urls)

def get_company_info_from_info_page(shop_url):
    """
    ショップURLに対して末尾にinfo.htmlを付与し、
    固定の企業情報ページHTMLから、
    <dl>内の<dt>タグを調査して「株式会社」を含むテキストを会社名として抽出し、
    会社名の直後には必ず「〒」が続く前提で、その直前までを会社名とみなす。
    また、TEL:の後に続く電話番号を抽出する。
    ※有限会社は抽出対象外です。
    """
    info_url = shop_url.rstrip('/') + '/info.html'
    print(f"取得する企業情報ページ: {info_url}")
    
    try:
        response = requests.get(info_url, timeout=15)
        response.raise_for_status()
    except Exception as e:
        print("企業情報ページの取得に失敗しました:", e)
        return "Not Found", "Not Found"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    company_name = "Not Found"
    dl_tag = soup.find("dl")
    if dl_tag:
        dt_tags = dl_tag.find_all("dt")
        for dt in dt_tags:
            dt_text = dt.get_text(strip=True)
            # 有限会社は抽出しないため、パターンは「株式会社」から始まるものだけに変更
            pattern = r'(株式会社)([^〒]+)(?=〒)'
            match = re.search(pattern, dt_text)
            if match:
                company_name = (match.group(1) + match.group(2)).strip()
                break
    
    telephone = "Not Found"
    tel_elem = soup.find(text=re.compile("TEL:"))
    if tel_elem:
        match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
        if match:
            telephone = match.group(1)
    
    return company_name, telephone

if __name__ == "__main__":
    # 既存の企業リスト（ショップURLのみを記載したCSV）のファイルパス
    existing_companies_file = "./rakuten_scraping.csv"
    # 既存のショップURLを読み込む（存在する場合）
    existing_shops = set()
    if os.path.exists(existing_companies_file):
        print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
        with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_url = row.get("shop_url")
                if shop_url:
                    existing_shops.add(shop_url)
        print(f"既存のショップURL数: {len(existing_shops)}")
    else:
        print("既存の企業リストが見つかりません。")

    # 1) 対象の楽天カテゴリ／検索結果ページのURLを入力
    print("例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション")
    while True:
        input_url = input("スクレイピング対象URLを入力してください: ").strip()
        if not input_url.startswith("https://"):
            print("URLが不正です。先頭がhttps:// で始まる必要があります。\n")
            continue
        else:
            print("スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。")
            break

    scraper = RakutenScraper(input_url)

    # 2) 初回リクエストでリンクを取得
    first_links = scraper.simple_request(input_url, first=True)
    if not first_links:
        print("初回のリクエストでリンクが取得できませんでした。終了します。")
        sys.exit(0)

    # 3) 初回で取得したリンクをさらに巡回してリンクを収集（BFS的に1階層のみ）
    #    ※ユーザーが途中で中断しても、これまでに集まったリンクで後続処理を行います。
    try:
        start_time = time.time()
        for link in first_links:
            # ここでは30分を上限として巡回
            if time.time() - start_time > 1800:
                print("30分経過したため、巡回を終了します。")
                break
            if link.startswith("http"):
                scraper.simple_request(link, first=False)
                time.sleep(random.uniform(1, 1.7))
                # 毎回、商品ページURLとショップURLを更新してチェック
                scraper.get_item_url()
                current_shop_urls = scraper.extract_shop_urls()
                print(f"現在のショップURL数: {len(current_shop_urls)}")
    except KeyboardInterrupt:
        print("\nユーザーによって中断されました。これまでのデータを元に後続の処理を実行します。")
    finally:
        # 最終的に再計算して全てのショップURLを確認
        item_urls = scraper.get_item_url()
        shop_urls = scraper.extract_shop_urls()
        print(f"\n最終的な商品ページURL数: {len(item_urls)}")
        print(f"取得したショップURLの数: {len(shop_urls)}")

        # 4) 各ショップURLに対して末尾にinfo.htmlを付与し、
        #    企業情報ページから企業名と電話番号を取得（既存のショップはスキップ）
        #    ※ここでinfo.html付きのURLも計算して、結果に追加します。
        results = []
        for shop_url in shop_urls:
            if shop_url in existing_shops:
                print(f"{shop_url} は既に抽出済みのため、スキップします。")
                continue
            # info.htmlを付与したURL
            info_url = shop_url.rstrip('/') + '/info.html'
            company_name, telephone = get_company_info_from_info_page(shop_url)
            results.append({
                "shop_url": shop_url,         # info.html付与前のショップURL
                "info_url": info_url,         # info.htmlを付与したURL
                "company_name": company_name,
                "telephone": telephone
            })
            time.sleep(random.uniform(1, 2))
        
        # 5) CSV保存用ディレクトリの作成
        csv_dir = "./csv_data/"
        if not os.path.exists(csv_dir):
            os.makedirs(csv_dir)
        
        # 6) 新たに抽出した企業情報をCSVに書き出し（ショップURL、info_url、企業名、TEL）
        filename = f"{today}-company_info.csv"
        output_path = os.path.join(csv_dir, filename)
        
        # Excelで開いたときに文字化けを防ぐため、BOM付きUTF-8で保存
        with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
            fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            for row in results:
                writer.writerow(row)
        
        print(f"\n--- CSV出力完了 ---\nファイル: {output_path}")
        
        # ① 既存の企業リスト（ショップURLのみ）の更新：新たに抽出したショップURLも追加して保存
        all_shops = existing_shops.union({res["shop_url"] for res in results})
        with open(existing_companies_file, 'w', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            writer.writeheader()
            for shop in all_shops:
                writer.writerow({"shop_url": shop})
        
        print(f"\n--- 既存企業リストの更新完了 ---\nファイル: {existing_companies_file}")
        print("処理が完了しました。")
# Out:
# 既存の企業リスト ./rakuten_scraping.csv を読み込みます。
# 既存のショップURL数: 0
# 例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション
# スクレイピング対象URLを入力してください:  https://search.rakuten.co.jp/search/mall/-/558873/?min=10000
# スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/?min=10000 | 既存リンク数: 0
# アクセス中: https://www.rakuten.co.jp/ | 既存リンク数: 456
# 現在のショップURL数: 7
# アクセス中: https://basket.step.rakuten.co.jp/rms/mall/bs/cartall/ | 既存リンク数: 1003
# 現在のショップURL数: 7
# アクセス中: https://event.rakuten.co.jp/notification/ | 既存リンク数: 1008
# 現在のショップURL数: 7
# アクセス中: https://coupon.rakuten.co.jp/myCoupon/%E6%A5%BD%E5%A4%A9%E5%B8%82%E5%A0%B4 | 既存リンク数: 1021
# 現在のショップURL数: 7
# アクセス中: https://ashiato.rakuten.co.jp/rms/sd/ashiato/vc | 既存リンク数: 1021
# 現在のショップURL数: 7
# アクセス中: https://my.bookmark.rakuten.co.jp/item | 既存リンク数: 1027
# 現在のショップURL数: 7
# アクセス中: https://order.my.rakuten.co.jp/ | 既存リンク数: 1027
# 現在のショップURL数: 7
# アクセス中: https://ichiba.faq.rakuten.net/ | 既存リンク数: 1027
# 現在のショップURL数: 7
# アクセス中: https://ichiba.faq.rakuten.net/form/item-guide | 既存リンク数: 1083
# 現在のショップURL数: 7
# アクセス中: https://www.rakuten.co.jp/ec/?camp=701100000008vIp&scid=wi_ich_common | 既存リンク数: 1085
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 現在のショップURL数: 7
# アクセス中: https://event.rakuten.co.jp/campaign/supersale/?l-id=search_browse_pc_header_top | 既存リンク数: 1161
# 現在のショップURL数: 7
# アクセス中: https://www.rakuten.co.jp | 既存リンク数: 1308
# 現在のショップURL数: 7
# アクセス中: https://search.rakuten.co.jp/search/mall/-/551177/?min=10000 | 既存リンク数: 1308
# 現在のショップURL数: 11
# アクセス中: https://www.rakuten.co.jp/category/558873/ | 既存リンク数: 1665
# 現在のショップURL数: 21
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/?min=10000&used=0 | 既存リンク数: 2056
# 現在のショップURL数: 21
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/?min=10000&used=1 | 既存リンク数: 2342
# 現在のショップURL数: 22
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg5002023/?min=10000 | 既存リンク数: 2656
# 現在のショップURL数: 22
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000886/?min=10000 | 既存リンク数: 2658
# 現在のショップURL数: 27
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000881/?min=10000 | 既存リンク数: 2941
# 現在のショップURL数: 29
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000873/?min=10000 | 既存リンク数: 3255
# 現在のショップURL数: 31
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000883/?min=10000 | 既存リンク数: 3569
# 現在のショップURL数: 31
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000878/?min=10000 | 既存リンク数: 3852
# 現在のショップURL数: 32
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1004016/?min=10000 | 既存リンク数: 4136
# 現在のショップURL数: 33
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000876/?min=10000 | 既存リンク数: 4444
# 現在のショップURL数: 37
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016061/?min=10000 | 既存リンク数: 4729
# 現在のショップURL数: 40
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000877/?min=10000 | 既存リンク数: 5025
# 現在のショップURL数: 42
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000875/?min=10000 | 既存リンク数: 5320
# 現在のショップURL数: 46
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000874/?min=10000 | 既存リンク数: 5595
# 現在のショップURL数: 49
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000884/?min=10000 | 既存リンク数: 5858
# 現在のショップURL数: 50
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000885/?min=10000 | 既存リンク数: 6116
# 現在のショップURL数: 50
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1004015/?min=10000 | 既存リンク数: 6390
# 現在のショップURL数: 50
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000882/?min=10000 | 既存リンク数: 6637
# 現在のショップURL数: 51
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000880/?min=10000 | 既存リンク数: 6905
# 現在のショップURL数: 56
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000879/?min=10000 | 既存リンク数: 7185
# 現在のショップURL数: 58
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016062/?min=10000 | 既存リンク数: 7426
# 現在のショップURL数: 60
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000887/?min=10000 | 既存リンク数: 7585
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000317/?min=10000 | 既存リンク数: 7865
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000318/?min=10000 | 既存リンク数: 8127
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000319/?min=10000 | 既存リンク数: 8389
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000320/?min=10000 | 既存リンク数: 8648
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001534/?min=10000 | 既存リンク数: 8908
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001535/?min=10000 | 既存リンク数: 9162
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001536/?min=10000 | 既存リンク数: 9414
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001537/?min=10000 | 既存リンク数: 9719
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001538/?min=10000 | 既存リンク数: 9987
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001539/?min=10000 | 既存リンク数: 10241
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001540/?min=10000 | 既存リンク数: 10475
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001541/?min=10000 | 既存リンク数: 10665
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001542/?min=10000 | 既存リンク数: 10791
# 現在のショップURL数: 62
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1002995/?min=10000 | 既存リンク数: 10877
# 現在のショップURL数: 63
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000409/?min=10000 | 既存リンク数: 11140
# 現在のショップURL数: 67
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000410/?min=10000 | 既存リンク数: 11424
# 現在のショップURL数: 70
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000411/?min=10000 | 既存リンク数: 11707
# 現在のショップURL数: 70
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000412/?min=10000 | 既存リンク数: 11986
# 現在のショップURL数: 71
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000413/?min=10000 | 既存リンク数: 12250
# 現在のショップURL数: 71
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000414/?min=10000 | 既存リンク数: 12500
# 現在のショップURL数: 71
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000415/?min=10000 | 既存リンク数: 12749
# 現在のショップURL数: 71
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000416/?min=10000 | 既存リンク数: 12998
# 現在のショップURL数: 71
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000417/?min=10000 | 既存リンク数: 13257
# 現在のショップURL数: 72
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000418/?min=10000 | 既存リンク数: 13545
# 現在のショップURL数: 73
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1002251/?min=10000 | 既存リンク数: 13806
# 現在のショップURL数: 73
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1002305/?min=10000 | 既存リンク数: 14064
# 現在のショップURL数: 73
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1002636/?min=10000 | 既存リンク数: 14342
# 現在のショップURL数: 74
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000588/?min=10000 | 既存リンク数: 14602
# 現在のショップURL数: 79
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000929/?min=10000 | 既存リンク数: 14843
# 現在のショップURL数: 82
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000810/?min=10000 | 既存リンク数: 15131
# 現在のショップURL数: 84
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1002307/?min=10000 | 既存リンク数: 15377
# 現在のショップURL数: 86
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001896/?min=10000 | 既存リンク数: 15610
# 現在のショップURL数: 90
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001901/?min=10000 | 既存リンク数: 15803
# 現在のショップURL数: 92
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001966/?min=10000 | 既存リンク数: 16058
# 現在のショップURL数: 92
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000595/?min=10000 | 既存リンク数: 16237
# 現在のショップURL数: 93
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001624/?min=10000 | 既存リンク数: 16449
# 現在のショップURL数: 94
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001971/?min=10000 | 既存リンク数: 16707
# 現在のショップURL数: 94
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000787/?min=10000 | 既存リンク数: 16987
# 現在のショップURL数: 95
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001811/?min=10000 | 既存リンク数: 17266
# 現在のショップURL数: 96
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1002472/?min=10000 | 既存リンク数: 17523
# 現在のショップURL数: 97
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1024305/?min=10000 | 既存リンク数: 17782
# 現在のショップURL数: 97
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1001906/?min=10000 | 既存リンク数: 17927
# 現在のショップURL数: 104
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1012735/?min=10000 | 既存リンク数: 18208
# 現在のショップURL数: 104
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000838/?min=10000 | 既存リンク数: 18458
# 現在のショップURL数: 105
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000904/?min=10000 | 既存リンク数: 18713
# 現在のショップURL数: 105
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000902/?min=10000 | 既存リンク数: 18987
# 現在のショップURL数: 107
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000905/?min=10000 | 既存リンク数: 19250
# 現在のショップURL数: 107
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1000903/?min=10000 | 既存リンク数: 19497
# 現在のショップURL数: 107
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003441/?min=10000 | 既存リンク数: 19726
# 現在のショップURL数: 107
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005530/?min=10000 | 既存リンク数: 19937
# 現在のショップURL数: 107
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003434/?min=10000 | 既存リンク数: 20154
# 現在のショップURL数: 107
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003435/?min=10000 | 既存リンク数: 20363
# 現在のショップURL数: 108
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003799/?min=10000 | 既存リンク数: 20610
# 現在のショップURL数: 109
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1007662/?min=10000 | 既存リンク数: 20861
# 現在のショップURL数: 109
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003673/?min=10000 | 既存リンク数: 21101
# 現在のショップURL数: 110
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003439/?min=10000 | 既存リンク数: 21328
# 現在のショップURL数: 112
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005535/?min=10000 | 既存リンク数: 21574
# 現在のショップURL数: 112
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003438/?min=10000 | 既存リンク数: 21808
# 現在のショップURL数: 113
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1009082/?min=10000 | 既存リンク数: 22031
# 現在のショップURL数: 114
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1036998/?min=10000 | 既存リンク数: 22263
# 現在のショップURL数: 114
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003670/?min=10000 | 既存リンク数: 22490
# 現在のショップURL数: 115
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003436/?min=10000 | 既存リンク数: 22728
# 現在のショップURL数: 115
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003442/?min=10000 | 既存リンク数: 22994
# 現在のショップURL数: 120
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003432/?min=10000 | 既存リンク数: 23202
# 現在のショップURL数: 122
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003674/?min=10000 | 既存リンク数: 23426
# 現在のショップURL数: 122
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008834/?min=10000 | 既存リンク数: 23647
# 現在のショップURL数: 123
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1007659/?min=10000 | 既存リンク数: 23855
# 現在のショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003675/?min=10000 | 既存リンク数: 24110
# 現在のショップURL数: 127
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003782/?min=10000 | 既存リンク数: 24336
# 現在のショップURL数: 127
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003784/?min=10000 | 既存リンク数: 24536
# 現在のショップURL数: 127
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003787/?min=10000 | 既存リンク数: 24737
# 現在のショップURL数: 127
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003786/?min=10000 | 既存リンク数: 24952
# 現在のショップURL数: 128
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005803/?min=10000 | 既存リンク数: 25191
# 現在のショップURL数: 128
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005802/?min=10000 | 既存リンク数: 25387
# 現在のショップURL数: 128
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003791/?min=10000 | 既存リンク数: 25628
# 現在のショップURL数: 128
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005801/?min=10000 | 既存リンク数: 25863
# 現在のショップURL数: 129
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003785/?min=10000 | 既存リンク数: 26095
# 現在のショップURL数: 129
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1007663/?min=10000 | 既存リンク数: 26322
# 現在のショップURL数: 131
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003789/?min=10000 | 既存リンク数: 26544
# 現在のショップURL数: 132
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016450/?min=10000 | 既存リンク数: 26773
# 現在のショップURL数: 132
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003788/?min=10000 | 既存リンク数: 27014
# 現在のショップURL数: 133
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003790/?min=10000 | 既存リンク数: 27216
# 現在のショップURL数: 134
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1003783/?min=10000 | 既存リンク数: 27428
# 現在のショップURL数: 135
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005804/?min=10000 | 既存リンク数: 27645
# 現在のショップURL数: 136
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1005800/?min=10000 | 既存リンク数: 27859
# 現在のショップURL数: 137
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008858/?min=10000 | 既存リンク数: 28068
# 現在のショップURL数: 138
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016451/?min=10000 | 既存リンク数: 28282
# 現在のショップURL数: 138
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1007665/?min=10000 | 既存リンク数: 28486
# 現在のショップURL数: 140
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008809/?min=10000 | 既存リンク数: 28689
# 現在のショップURL数: 140
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008819/?min=10000 | 既存リンク数: 28869
# 現在のショップURL数: 140
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008813/?min=10000 | 既存リンク数: 29063
# 現在のショップURL数: 141
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008808/?min=10000 | 既存リンク数: 29291
# 現在のショップURL数: 141
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008814/?min=10000 | 既存リンク数: 29506
# 現在のショップURL数: 142
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008821/?min=10000 | 既存リンク数: 29709
# 現在のショップURL数: 143
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008810/?min=10000 | 既存リンク数: 29892
# 現在のショップURL数: 143
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008825/?min=10000 | 既存リンク数: 30112
# 現在のショップURL数: 144
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008811/?min=10000 | 既存リンク数: 30319
# 現在のショップURL数: 145
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008827/?min=10000 | 既存リンク数: 30515
# 現在のショップURL数: 145
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008820/?min=10000 | 既存リンク数: 30739
# 現在のショップURL数: 145
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008826/?min=10000 | 既存リンク数: 30924
# 現在のショップURL数: 146
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008830/?min=10000 | 既存リンク数: 31128
# 現在のショップURL数: 147
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008815/?min=10000 | 既存リンク数: 31331
# 現在のショップURL数: 148
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008828/?min=10000 | 既存リンク数: 31538
# 現在のショップURL数: 151
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008817/?min=10000 | 既存リンク数: 31761
# 現在のショップURL数: 152
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008818/?min=10000 | 既存リンク数: 31992
# 現在のショップURL数: 153
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008824/?min=10000 | 既存リンク数: 32206
# 現在のショップURL数: 153
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008816/?min=10000 | 既存リンク数: 32431
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008831/?min=10000 | 既存リンク数: 32653
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013412/?min=10000 | 既存リンク数: 32869
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008861/?min=10000 | 既存リンク数: 33033
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016419/?min=10000 | 既存リンク数: 33204
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016409/?min=10000 | 既存リンク数: 33378
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008859/?min=10000 | 既存リンク数: 33535
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1039853/?min=10000 | 既存リンク数: 33690
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016418/?min=10000 | 既存リンク数: 33865
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016404/?min=10000 | 既存リンク数: 34032
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008862/?min=10000 | 既存リンク数: 34198
# 現在のショップURL数: 154
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016423/?min=10000 | 既存リンク数: 34369
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016406/?min=10000 | 既存リンク数: 34522
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1008860/?min=10000 | 既存リンク数: 34680
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016416/?min=10000 | 既存リンク数: 34830
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1040160/?min=10000 | 既存リンク数: 34985
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016411/?min=10000 | 既存リンク数: 35140
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016424/?min=10000 | 既存リンク数: 35284
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016412/?min=10000 | 既存リンク数: 35415
# 現在のショップURL数: 155
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016420/?min=10000 | 既存リンク数: 35567
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016410/?min=10000 | 既存リンク数: 35733
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1040214/?min=10000 | 既存リンク数: 35882
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011173/?min=10000 | 既存リンク数: 36098
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011174/?min=10000 | 既存リンク数: 36249
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011167/?min=10000 | 既存リンク数: 36389
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011172/?min=10000 | 既存リンク数: 36525
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011176/?min=10000 | 既存リンク数: 36666
# 現在のショップURL数: 156
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013352/?min=10000 | 既存リンク数: 36800
# 現在のショップURL数: 157
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1045745/?min=10000 | 既存リンク数: 36953
# 現在のショップURL数: 157
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011180/?min=10000 | 既存リンク数: 37132
# 現在のショップURL数: 158
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013351/?min=10000 | 既存リンク数: 37292
# 現在のショップURL数: 158
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011171/?min=10000 | 既存リンク数: 37444
# 現在のショップURL数: 159
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1014341/?min=10000 | 既存リンク数: 37605
# 現在のショップURL数: 159
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1045744/?min=10000 | 既存リンク数: 37769
# 現在のショップURL数: 159
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011179/?min=10000 | 既存リンク数: 37942
# 現在のショップURL数: 159
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1015140/?min=10000 | 既存リンク数: 38104
# 現在のショップURL数: 162
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011178/?min=10000 | 既存リンク数: 38271
# 現在のショップURL数: 162
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1019419/?min=10000 | 既存リンク数: 38465
# 現在のショップURL数: 162
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1011175/?min=10000 | 既存リンク数: 38641
# 現在のショップURL数: 162
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1018995/?min=10000 | 既存リンク数: 38782
# 現在のショップURL数: 162
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1015141/?min=10000 | 既存リンク数: 38946
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1015139/?min=10000 | 既存リンク数: 39099
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013643/?min=10000 | 既存リンク数: 39245
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013642/?min=10000 | 既存リンク数: 39375
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013644/?min=10000 | 既存リンク数: 39524
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013745/?min=10000 | 既存リンク数: 39664
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013746/?min=10000 | 既存リンク数: 39860
# 現在のショップURL数: 163
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013747/?min=10000 | 既存リンク数: 40059
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013796/?min=10000 | 既存リンク数: 40265
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013797/?min=10000 | 既存リンク数: 40373
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1029949/?min=10000 | 既存リンク数: 40497
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013798/?min=10000 | 既存リンク数: 40612
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1013799/?min=10000 | 既存リンク数: 40727
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016380/?min=10000 | 既存リンク数: 40845
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016381/?min=10000 | 既存リンク数: 41068
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016382/?min=10000 | 既存リンク数: 41321
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016383/?min=10000 | 既存リンク数: 41533
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016384/?min=10000 | 既存リンク数: 41672
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1016385/?min=10000 | 既存リンク数: 41816
# 現在のショップURL数: 165
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1037121/?min=10000 | 既存リンク数: 41977
# 現在のショップURL数: 168
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1037122/?min=10000 | 既存リンク数: 42125
# 現在のショップURL数: 169
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1037123/?min=10000 | 既存リンク数: 42317
# 現在のショップURL数: 169
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1037124/?min=10000 | 既存リンク数: 42472
# 現在のショップURL数: 169
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1037125/?min=10000 | 既存リンク数: 42622
# 現在のショップURL数: 169
# アクセス中: https://search.rakuten.co.jp/search/mall/-/558873/tg1
store/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ever-green/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/crossface/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/u-oak/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sshk/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/rex-2nd/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/organweb/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/piecelife/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/importshopdouble/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ikedayouhinten/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f252140-maibara/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/neoglobe/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/lbreath/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ms-inuzuka/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kalulu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kinetics-tokyo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tooo-you/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/firstline/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/apworld/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kokubo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/reisouclub/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/s-specchio/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/seoulcollection/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/suavetribe/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/cliffedge/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/realdeal-sendai/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ragtime001/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/auc-marks-run/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/z-mall/info.html
#
# --- CSV出力完了 ---
# ファイル: ./csv_data/2025-03-07-company_info.csv
#
# --- 既存企業リストの更新完了 ---
# ファイル: ./rakuten_scraping.csv
# 処理が完了しました。

# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import sys
import re
import csv

today = str(datetime.date.today())

class RakutenScraper:
    """
    楽天のカテゴリページや検索結果ページから再帰的にリンクを収集し、
    商品ページURLから「ショップURL」を抽出するサンプルクラス。
    できるだけ多くのショップURLを抽出します。
    """
    def __init__(self, base_url):
        self.base_url = base_url
        self.master_list = []        # 再帰的に収集したリンクを保存
        self.item_page_list = []     # 楽天の商品ページURLのみを格納
        self.shop_url_list = set()   # ショップURL（重複排除）を格納

    def simple_request(self, url, first=False):
        """
        指定URLのページから <a> タグの href を収集し、self.master_list に追加する。
        first=True のときは、取得したリンクリストを返す（初回のみ）。
        """
        print(f"アクセス中: {url} | 既存リンク数: {len(self.master_list)}")
        try:
            r = requests.get(url, timeout=(30.0, 47.5))
        except requests.exceptions.RequestException:
            return False

        if r.status_code == 200 and 'text/html' in r.headers.get('Content-Type', ''):
            soup = BeautifulSoup(r.content, 'html.parser')
            atag_list = soup.find_all('a')
            if first:
                unique_hrefs = []
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                    if href and (href not in unique_hrefs):
                        unique_hrefs.append(href)
                return unique_hrefs
            else:
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                return len(self.master_list)
        else:
            return False

    def get_item_url(self):
        """
        master_list に含まれるURLのうち、楽天の商品ページURLを抽出し、
        self.item_page_list を再計算する。
        例: https://item.rakuten.co.jp/ショップコード/商品ID/
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        self.item_page_list = []
        for url in self.master_list:
            if url and re.match(pattern, url):
                self.item_page_list.append(url)
        return self.item_page_list

    def extract_shop_urls(self, existing_shops=None):
        """
        item_page_list の各URLからショップコードを抜き出し、
        https://www.rakuten.co.jp/ショップコード/ の形でショップURLを生成します。
        既存のショップURL（existing_shops）と重複していない場合のみ追加します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        shop_urls = set()
        for item_url in self.item_page_list:
            m = re.match(pattern, item_url)
            if m:
                shop_code = m.group(1)
                shop_url = f"https://www.rakuten.co.jp/{shop_code}/"
                # 既存のショップURLと重複していなければ追加
                if existing_shops is None or shop_url not in existing_shops:
                    shop_urls.add(shop_url)
        self.shop_url_list = shop_urls
        return list(shop_urls)

def get_company_info_from_info_page(shop_url):
    """
    ショップURLに対して末尾にinfo.htmlを付与し、
    固定の企業情報ページHTMLから、<dl>内の<dt>タグのテキストを取得します。
    そのテキストに「株式会社」が含まれていれば企業名として採用し、
    ※「有限会社」が含まれているものは抽出対象外とします。
    同時にTEL:の後の電話番号も抽出します。
    """
    info_url = shop_url.rstrip('/') + '/info.html'
    print(f"取得する企業情報ページ: {info_url}")
    
    try:
        response = requests.get(info_url, timeout=15)
        response.raise_for_status()
    except Exception as e:
        print("企業情報ページの取得に失敗しました:", e)
        return "Not Found", "Not Found"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    company_name = "Not Found"
    phone_number = "Not Found"
    
    dl_tag = soup.find("dl")
    if dl_tag:
        dt_tags = dl_tag.find_all("dt")
        for dt in dt_tags:
            dt_text = dt.get_text(strip=True)
            # dtタグのテキストに「株式会社」が含まれており、
            # なおかつ「有限会社」が含まれていなければ企業名として採用
            if "株式会社" in dt_text and "有限会社" not in dt_text:
                company_name = dt_text
                break

    tel_elem = soup.find(text=re.compile("TEL:"))
    if tel_elem:
        match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
        if match:
            phone_number = match.group(1)
    
    return company_name, phone_number

if __name__ == "__main__":
    # 既存の企業リスト（ショップURLのみを記載したCSV）のファイルパス
    existing_companies_file = "./rakuten_scraping.csv"
    # 既存のショップURLを読み込む（存在する場合）
    existing_shops = set()
    if os.path.exists(existing_companies_file):
        print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
        with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_url = row.get("shop_url", "").strip()
                if shop_url:
                    existing_shops.add(shop_url)
        print(f"既存のショップURL数: {len(existing_shops)}")
    else:
        print("既存の企業リストが見つかりません。")

    # 1) 対象の楽天カテゴリ／検索結果ページのURLを入力
    print("例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション")
    while True:
        input_url = input("スクレイピング対象URLを入力してください: ").strip()
        if not input_url.startswith("https://"):
            print("URLが不正です。先頭がhttps:// で始まる必要があります。\n")
            continue
        else:
            print("スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。")
            break

    scraper = RakutenScraper(input_url)

    # 2) 初回リクエストでリンクを取得
    first_links = scraper.simple_request(input_url, first=True)
    if not first_links:
        print("初回のリクエストでリンクが取得できませんでした。終了します。")
        sys.exit(0)

    # 3) 初回で取得したリンクをさらに巡回してリンクを収集（BFS的に1階層のみ）
    #    ※ユーザーが途中で中断しても、これまでに集まったリンクで後続処理を行います。
    try:
        start_time = time.time()
        for link in first_links:
            # ここでは30分を上限として巡回
            if time.time() - start_time > 1800:
                print("30分経過したため、巡回を終了します。")
                break
            if link.startswith("http"):
                scraper.simple_request(link, first=False)
                time.sleep(random.uniform(1, 1.7))
                # 毎回、商品ページURLとショップURLを更新してチェック
                scraper.get_item_url()
                current_shop_urls = scraper.extract_shop_urls(existing_shops)
                print(f"現在の新規ショップURL数: {len(current_shop_urls)}")
    except KeyboardInterrupt:
        print("\nユーザーによって中断されました。これまでのデータを元に後続の処理を実行します。")
    finally:
        # 最終的に再計算して全てのショップURLを確認（重複は除外済み）
        item_urls = scraper.get_item_url()
        shop_urls = scraper.extract_shop_urls(existing_shops)
        print(f"\n最終的な商品ページURL数: {len(item_urls)}")
        print(f"取得した新規ショップURLの数: {len(shop_urls)}")

        # 4) 各ショップURLに対して末尾にinfo.htmlを付与し、
        #    企業情報ページから企業名と電話番号を取得
        results = []
        for shop_url in shop_urls:
            info_url = shop_url.rstrip('/') + '/info.html'
            company_name, telephone = get_company_info_from_info_page(shop_url)
            results.append({
                "shop_url": shop_url,         # info.html付与前のショップURL
                "info_url": info_url,           # info.htmlを付与したURL
                "company_name": company_name,
                "telephone": telephone
            })
            time.sleep(random.uniform(1, 2))
        
        # 5) CSV保存用ディレクトリの作成
        csv_dir = "./csv_data/"
        if not os.path.exists(csv_dir):
            os.makedirs(csv_dir)
        
        # 6) 新たに抽出した企業情報をCSVに書き出し（ショップURL、info_url、企業名、TEL）
        filename = f"{today}-company_info.csv"
        output_path = os.path.join(csv_dir, filename)
        
        # Excelで開いたときに文字化けを防ぐため、BOM付きUTF-8で保存
        with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
            fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            for row in results:
                writer.writerow(row)
        
        print(f"\n--- CSV出力完了 ---\nファイル: {output_path}")
        
        # 既存の企業リスト（ショップURLのみ）に新たなショップURLを追加して更新
        all_shops = existing_shops.union({res["shop_url"] for res in results})
        with open(existing_companies_file, 'w', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            writer.writeheader()
            for shop in all_shops:
                writer.writerow({"shop_url": shop})
        
        print(f"\n--- 既存企業リストの更新完了 ---\nファイル: {existing_companies_file}")
        print("処理が完了しました。")
# Out:
# 既存の企業リスト ./rakuten_scraping.csv を読み込みます。
# 既存のショップURL数: 0
# 例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション
# スクレイピング対象URLを入力してください:  https://search.rakuten.co.jp/search/mall/-/101975/?min=10000
# スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000 | 既存リンク数: 0
# アクセス中: https://www.rakuten.co.jp/ | 既存リンク数: 284
# 現在の新規ショップURL数: 5
# アクセス中: https://basket.step.rakuten.co.jp/rms/mall/bs/cartall/ | 既存リンク数: 832
# 現在の新規ショップURL数: 5
# アクセス中: https://event.rakuten.co.jp/notification/ | 既存リンク数: 837
# 現在の新規ショップURL数: 5
# アクセス中: https://coupon.rakuten.co.jp/myCoupon/%E6%A5%BD%E5%A4%A9%E5%B8%82%E5%A0%B4 | 既存リンク数: 850
# 現在の新規ショップURL数: 5
# アクセス中: https://ashiato.rakuten.co.jp/rms/sd/ashiato/vc | 既存リンク数: 850
# 現在の新規ショップURL数: 5
# アクセス中: https://my.bookmark.rakuten.co.jp/item | 既存リンク数: 856
# 現在の新規ショップURL数: 5
# アクセス中: https://order.my.rakuten.co.jp/ | 既存リンク数: 856
# 現在の新規ショップURL数: 5
# アクセス中: https://ichiba.faq.rakuten.net/ | 既存リンク数: 856
# 現在の新規ショップURL数: 5
# アクセス中: https://ichiba.faq.rakuten.net/form/item-guide | 既存リンク数: 912
# 現在の新規ショップURL数: 5
# アクセス中: https://www.rakuten.co.jp/ec/?camp=701100000008vIp&scid=wi_ich_common | 既存リンク数: 914
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 現在の新規ショップURL数: 5
# アクセス中: https://event.rakuten.co.jp/campaign/supersale/?l-id=search_browse_pc_header_top | 既存リンク数: 990
# 現在の新規ショップURL数: 5
# アクセス中: https://www.rakuten.co.jp | 既存リンク数: 1137
# 現在の新規ショップURL数: 5
# アクセス中: https://search.rakuten.co.jp/search/mall/-/
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&ran=10010004589946135589&s=11 | 既存リンク数: 16515
# 現在の新規ショップURL数: 87
# アクセス中: https://item.rakuten.co.jp/alpen/7420102009/?variantId=74201020090000000 | 既存リンク数: 16535
# 現在の新規ショップURL数: 87
# アクセス中: https://review.rakuten.co.jp/item/1/207922_10286733/1.1/ | 既存リンク数: 16543
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&ran=40010000076501232660&s=11 | 既存リンク数: 16553
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=2 | 既存リンク数: 16597
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=3 | 既存リンク数: 16632
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=4 | 既存リンク数: 16657
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=5 | 既存リンク数: 16673
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=6 | 既存リンク数: 16705
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=7 | 既存リンク数: 16728
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=8 | 既存リンク数: 16808
# 現在の新規ショップURL数: 87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=9 | 既存リンク数: 16841
# 現在の新規ショップURL数: 87
# アクセス中: https://ichiba.faq.rakuten.net/detail/000006462 | 既存リンク数: 16878
# 現在の新規ショップURL数: 87
# アクセス中: https://ichiba.faq.rakuten.net/detail/000006436 | 既存リンク数: 16882
# 現在の新規ショップURL数: 87
# アクセス中: https://ichiba.faq.rakuten.net/detail/000006426 | 既存リンク数: 16883
# 現在の新規ショップURL数: 87
# アクセス中: https://ichiba.faq.rakuten.net/category/search-order/search-products | 既存リンク数: 16883
# 現在の新規ショップURL数: 87
# アクセス中: https://chat.ichiba.faq.rakuten.co.jp/Search | 既存リンク数: 16920
# 現在の新規ショップURL数: 87
# アクセス中: https://ranking.rakuten.co.jp/daily/101975/ | 既存リンク数: 16920
# 現在の新規ショップURL数: 87
# 30分経過したため、巡回を終了します。
#
# 最終的な商品ページURL数: 459
# 取得した新規ショップURLの数: 87
# 取得する企業情報ページ: https://www.rakuten.co.jp/biken-concierge/info.html
# C:\Users\to0ar\AppData\Local\Temp\ipykernel_6584\1487977519.py:123: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tel_elem = soup.find(text=re.compile("TEL:"))
# 取得する企業情報ページ: https://www.rakuten.co.jp/f182010-fukui/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kaguin/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/webbymono/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/euro-surplus/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/esports/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/field-seven/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/victorinox/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/twopedal/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/enetroom/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/nuuca/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f212105-ena/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/wild-1/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/manpyousyouten0802/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/e-kurashi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sportsx/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/oohashitent/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/lbreath/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kaitekicreate/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/captainstagstore/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f282201-kasai/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/founder/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/monmiya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/supersportsxebio/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/cyclemall/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/aeonbike/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/victoria-online/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/oc-style/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tansu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/northfeel/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/watermode/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tomount/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f082341-hokota/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/upi-outdoor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/a-price/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f281000-kobe/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hobbytoy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/importshopaqua/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f212113-minokamo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/alpen/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/naturum/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/premium-interior/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/naturum-outdoor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tokyocamp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/demode-keystation/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/aaa-corp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/passageshop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/otakaratuuhan/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/toyokuni/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/himaraya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f063614-kaneyama/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f252140-maibara/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/marine-mate/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/americana/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f082368-omitama/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/flaner/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f212059-seki/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/unidy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/palmy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/mecu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/yamatakanamono/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/m-outdoor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f122173-kashiwa/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/arimas/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/thetent/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f152137-tsubame/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/abctown/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/deandeluca/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/naturum-fashion/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/saunacamp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/apolloex/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/auc-roadster/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hilander/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/whatnot/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/maxshare/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/fujinami/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/takisyo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/r-tools/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/plywood/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sakaiya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kojitu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hermanherman/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bagshoparr/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/yoshikip2/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ga-living/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/insair/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ventlax/info.html
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 216
#     213 output_path = os.path.join(csv_dir, filename)
#     215 # Excelで開いたときに文字化けを防ぐため、BOM付きUTF-8で保存
# --> 216 with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
#     217     fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
#     218     writer = csv.DictWriter(f, fieldnames=fieldnames)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: './csv_data/2025-03-10-company_info.csv'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\to0ar\PROLE

# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import sys
import re
import csv

today = str(datetime.date.today())

class RakutenScraper:
    """
    楽天のカテゴリページや検索結果ページから再帰的にリンクを収集し、
    商品ページURLから「ショップURL」を抽出するサンプルクラス。
    できるだけ多くのショップURLを抽出します。
    """
    def __init__(self, base_url):
        self.base_url = base_url
        self.master_list = []        # 再帰的に収集したリンクを保存
        self.item_page_list = []     # 楽天の商品ページURLのみを格納
        self.shop_url_list = set()   # ショップURL（重複排除）を格納

    def simple_request(self, url, first=False):
        """
        指定URLのページから <a> タグの href を収集し、self.master_list に追加する。
        first=True のときは、取得したリンクリストを返す（初回のみ）。
        """
        print(f"アクセス中: {url} | 既存リンク数: {len(self.master_list)}")
        try:
            r = requests.get(url, timeout=(30.0, 47.5))
        except requests.exceptions.RequestException:
            return False

        if r.status_code == 200 and 'text/html' in r.headers.get('Content-Type', ''):
            soup = BeautifulSoup(r.content, 'html.parser')
            atag_list = soup.find_all('a')
            if first:
                unique_hrefs = []
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                    if href and (href not in unique_hrefs):
                        unique_hrefs.append(href)
                return unique_hrefs
            else:
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                return len(self.master_list)
        else:
            return False

    def get_item_url(self):
        """
        master_list に含まれるURLのうち、楽天の商品ページURLを抽出し、
        self.item_page_list を再計算する。
        例: https://item.rakuten.co.jp/ショップコード/商品ID/
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        self.item_page_list = []
        for url in self.master_list:
            if url and re.match(pattern, url):
                self.item_page_list.append(url)
        return self.item_page_list

    def extract_shop_urls(self, existing_shops=None):
        """
        item_page_list の各URLからショップコードを抜き出し、
        https://www.rakuten.co.jp/ショップコード/ の形でショップURLを生成します。
        既存のショップURL（existing_shops）と重複していない場合のみ追加します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        shop_urls = set()
        for item_url in self.item_page_list:
            m = re.match(pattern, item_url)
            if m:
                shop_code = m.group(1)
                shop_url = f"https://www.rakuten.co.jp/{shop_code}/"
                if existing_shops is None or shop_url not in existing_shops:
                    shop_urls.add(shop_url)
        self.shop_url_list = shop_urls
        return list(shop_urls)

def get_company_info_from_info_page(shop_url):
    """
    ショップURLに対して末尾にinfo.htmlを付与し、
    固定の企業情報ページHTMLから、<dl>内の<dt>タグのテキストを取得します。
    そのテキスト内で「株式会社」を含む部分を抽出し、
    ※「有限会社」が含まれているものは抽出対象外とします。
    TEL:の後の電話番号も抽出します。
    """
    info_url = shop_url.rstrip('/') + '/info.html'
    print(f"取得する企業情報ページ: {info_url}")
    
    try:
        response = requests.get(info_url, timeout=15)
        response.raise_for_status()
    except Exception as e:
        print("企業情報ページの取得に失敗しました:", e)
        return "Not Found", "Not Found"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    company_name = "Not Found"
    phone_number = "Not Found"
    
    dl_tag = soup.find("dl")
    if dl_tag:
        dt_tags = dl_tag.find_all("dt")
        for dt in dt_tags:
            dt_text = dt.get_text(" ", strip=True)
            if not dt_text:
                continue
            # 「株式会社」を含む部分を、余計な情報（〒やTEL等）が出現する前まで抽出
            pattern = r'(.*?株式会社.*?)(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
            match = re.search(pattern, dt_text)
            if match:
                company_name = match.group(1).strip()
                break

    tel_elem = soup.find(text=re.compile("TEL:"))
    if tel_elem:
        match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
        if match:
            phone_number = match.group(1)
    
    return company_name, phone_number

if __name__ == "__main__":
    # 既存の企業リスト（ショップURLのみを記載したCSV）のファイルパス（相対パス）
    existing_companies_file = "./extracted_companies.csv"
    existing_shops = set()
    if os.path.exists(existing_companies_file):
        print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
        with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_url = row.get("shop_url", "").strip()
                if shop_url:
                    existing_shops.add(shop_url)
        print(f"既存のショップURL数: {len(existing_shops)}")
    else:
        print("既存の企業リストが見つかりません。")

    print("例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション")
    while True:
        input_url = input("スクレイピング対象URLを入力してください: ").strip()
        if not input_url.startswith("https://"):
            print("URLが不正です。先頭がhttps:// で始まる必要があります。\n")
            continue
        else:
            print("スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。")
            break

    scraper = RakutenScraper(input_url)

    first_links = scraper.simple_request(input_url, first=True)
    if not first_links:
        print("初回のリクエストでリンクが取得できませんでした。終了します。")
        sys.exit(0)

    try:
        start_time = time.time()
        for link in first_links:
            if time.time() - start_time > 1800:
                print("30分経過したため、巡回を終了します。")
                break
            if link.startswith("http"):
                scraper.simple_request(link, first=False)
                time.sleep(random.uniform(1, 1.7))
                scraper.get_item_url()
                current_shop_urls = scraper.extract_shop_urls(existing_shops)
                print(f"現在の新規ショップURL数: {len(current_shop_urls)}")
    except KeyboardInterrupt:
        print("\nユーザーによって中断されました。これまでのデータを元に後続の処理を実行します。")
    finally:
        item_urls = scraper.get_item_url()
        shop_urls = scraper.extract_shop_urls(existing_shops)
        print(f"\n最終的な商品ページURL数: {len(item_urls)}")
        print(f"取得した新規ショップURLの数: {len(shop_urls)}")

        results = []
        for shop_url in shop_urls:
            info_url = shop_url.rstrip('/') + '/info.html'
            company_name, telephone = get_company_info_from_info_page(shop_url)
            results.append({
                "shop_url": shop_url,
                "info_url": info_url,
                "company_name": company_name,
                "telephone": telephone
            })
            time.sleep(random.uniform(1, 2))
        
        csv_dir = "./csv_data/"
        if not os.path.exists(csv_dir):
            os.makedirs(csv_dir)
        
        filename = f"{today}-company_info.csv"
        output_path = os.path.join(csv_dir, filename)
        
        with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
            fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            for row in results:
                writer.writerow(row)
        
        print(f"\n--- CSV出力完了 ---\nファイル: {output_path}")
        
        # 既存の企業リストに新規抽出されたショップURLのみを追記する（既存の内容は保持）
        new_shops = {res["shop_url"] for res in results} - existing_shops
        if new_shops:
            with open(existing_companies_file, 'a', newline='', encoding='utf-8-sig') as f:
                writer = csv.DictWriter(f, fieldnames=["shop_url"])
                for shop in new_shops:
                    writer.writerow({"shop_url": shop})
            print(f"\n--- 新規ショップURLを既存企業リストに追加しました ---\nファイル: {existing_companies_file}")
        else:
            print("新しいショップURLは見つかりませんでした。")
        
        print("処理が完了しました。")
# Out:
# 既存の企業リストが見つかりません。
# 例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション
# スクレイピング対象URLを入力してください:  https://search.rakuten.co.jp/search/mall/-/565210/?min=10000
# スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/?min=10
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019634/?min=10000 | 既存リンク数: 41513
# 現在の新規ショップURL数: 111
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019635/?min=10000 | 既存リンク数: 41703
# 現在の新規ショップURL数: 112
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019636/?min=10000 | 既存リンク数: 41878
# 現在の新規ショップURL数: 112
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019637/?min=10000 | 既存リンク数: 42073
# 現在の新規ショップURL数: 112
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019638/?min=10000 | 既存リンク数: 42250
# 現在の新規ショップURL数: 112
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019639/?min=10000 | 既存リンク数: 42411
# 現在の新規ショップURL数: 113
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019640/?min=10000 | 既存リンク数: 42567
# 現在の新規ショップURL数: 113
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019641/?min=10000 | 既存リンク数: 42708
# 現在の新規ショップURL数: 114
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019642/?min=10000 | 既存リンク数: 42908
# 現在の新規ショップURL数: 114
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019643/?min=10000 | 既存リンク数: 43020
# 現在の新規ショップURL数: 118
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019644/?min=10000 | 既存リンク数: 43214
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019645/?min=10000 | 既存リンク数: 43395
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019646/?min=10000 | 既存リンク数: 43551
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019647/?min=10000 | 既存リンク数: 43687
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019648/?min=10000 | 既存リンク数: 43816
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019649/?min=10000 | 既存リンク数: 43957
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019650/?min=10000 | 既存リンク数: 44082
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019651/?min=10000 | 既存リンク数: 44211
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019652/?min=10000 | 既存リンク数: 44344
# 現在の新規ショップURL数: 119
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019653/?min=10000 | 既存リンク数: 44485
# 現在の新規ショップURL数: 120
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019654/?min=10000 | 既存リンク数: 44648
# 現在の新規ショップURL数: 124
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019655/?min=10000 | 既存リンク数: 44853
# 現在の新規ショップURL数: 125
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019656/?min=10000 | 既存リンク数: 45039
# 現在の新規ショップURL数: 125
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019657/?min=10000 | 既存リンク数: 45224
# 現在の新規ショップURL数: 125
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019658/?min=10000 | 既存リンク数: 45336
# 現在の新規ショップURL数: 125
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019659/?min=10000 | 既存リンク数: 45493
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019660/?min=10000 | 既存リンク数: 45618
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019661/?min=10000 | 既存リンク数: 45724
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019662/?min=10000 | 既存リンク数: 45834
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019663/?min=10000 | 既存リンク数: 45959
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019664/?min=10000 | 既存リンク数: 46079
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019665/?min=10000 | 既存リンク数: 46197
# 現在の新規ショップURL数: 126
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019666/?min=10000 | 既存リンク数: 46326
# 現在の新規ショップURL数: 127
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019667/?min=10000 | 既存リンク数: 46467
# 現在の新規ショップURL数: 129
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019668/?min=10000 | 既存リンク数: 46607
# 現在の新規ショップURL数: 129
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019669/?min=10000 | 既存リンク数: 46764
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019670/?min=10000 | 既存リンク数: 46896
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019671/?min=10000 | 既存リンク数: 47009
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019672/?min=10000 | 既存リンク数: 47097
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019673/?min=10000 | 既存リンク数: 47167
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019674/?min=10000 | 既存リンク数: 47226
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1019675/?min=10000 | 既存リンク数: 47345
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1030929/?min=10000 | 既存リンク数: 47474
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1030930/?min=10000 | 既存リンク数: 47576
# 現在の新規ショップURL数: 130
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1030932/?min=10000 | 既存リンク数: 47692
# 現在の新規ショップURL数: 131
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1030931/?min=10000 | 既存リンク数: 47822
# 現在の新規ショップURL数: 131
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/tg1037231/?min=10000 | 既存リンク数: 47950
# 現在の新規ショップURL数: 132
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/?min=10000 | 既存リンク数: 48134
# 現在の新規ショップURL数: 132
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/?country=99&min=10000 | 既存リンク数: 48150
# 現在の新規ショップURL数: 132
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/?min=10000&review=4.5 | 既存リンク数: 48230
# 現在の新規ショップURL数: 132
# アクセス中: https://search.rakuten.co.jp/search/mall/-/565210/?min=10000
info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bonaventura-shop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tube-tube/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/nono-shop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/fibreno/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/komecase/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/unby/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kangenya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f402184-kasuga/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/vt-store/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tansu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/katte-me/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/la-foresta/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/watermode/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/i-need-more-shoes/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bestgallery/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/unveil-bag/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/auc-ozatoya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bleucommebleu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/homedecor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/torato/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/decorus/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/a-price/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/rapturecc/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/maruzen-bag/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/importshopaqua/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tilia/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/danjo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sacs-bar/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kabansoko/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/import-ss-shop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/premium-interior/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/gobangai/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/washington/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/vacchetta-topkapi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/mznet/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/touzai/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/palmspalms/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/angers/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/passageshop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/iwasa-zouri/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/clew/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ebisuyabag/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/masugi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/harnessel/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/mujirushi-ryohin/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/jackpot/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/e-mono-online-shop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hallelujah/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/selfishfk/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/yamamotojp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/jamu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f131075-sumida/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/vreason/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/galleria/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/marienamaki/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/alfurd/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kalulu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/precious-place/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/glencheck/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/miniyama/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hana-kura-kaban/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/adele-cherie/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/jewelnarose/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f112330-kitamoto/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/milesto/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/escale/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ann-inter/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/better/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sneaker-soko/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/irisplaza-r/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/lastnote/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/o-living/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/anne-group/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/abctown/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sutetuchi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f182095-echizen/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sakaeshop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/zakka-box/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/roiscompany/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kanko/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/futaba-bag/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/plywood/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/septwolves/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bruno-official/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/zerohalliburton-store/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tasche-jack/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/manhattanpassage/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/fkikaku/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/angelina1/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/imaibag/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bungudo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bagshoparr/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/gstar-shop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/x-sell/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sentire/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/clozest/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ino-kichi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/seoulcollection/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/standardsupply/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/matsuzakaya/info.html
#
# --- CSV出力完了 ---
# ファイル: ./csv_data/2025-03-10-company_info.csv
#
# --- 新規ショップURLを既存企業リストに追加しました ---
# ファイル: ./extracted_companies.csv
# 処理が完了しました。

# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import sys
import re
import csv
from urllib.parse import urljoin

today = str(datetime.date.today())

def get_shop_id(shop_url):
    """
    ショップURL（例: https://www.rakuten.co.jp/SHOPID/）からSHOPIDを抽出します。
    """
    pattern = r'^https://www\.rakuten\.co\.jp/([^/]+)/?$'
    m = re.match(pattern, shop_url)
    if m:
        return m.group(1)
    else:
        return None

class RakutenScraper:
    """
    楽天のカテゴリページや検索結果ページから再帰的にリンクを収集し、
    商品ページURLからショップURLを抽出するサンプルクラスです。
    """
    def __init__(self, base_url):
        self.base_url = base_url
        self.master_list = []        # 収集した全リンク
        self.item_page_list = []     # 楽天の商品ページURLのみ
        self.shop_url_list = set()   # 重複排除済みショップURL

    def simple_request(self, url, first=False):
        """
        指定されたURLのページから <a> タグの href を収集し、self.master_list に追加します。
        first=True の場合、初回に取得したリンクリストを返します。
        """
        print(f"アクセス中: {url} | 既存リンク数: {len(self.master_list)}")
        try:
            r = requests.get(url, timeout=(30.0, 47.5))
        except requests.exceptions.RequestException:
            return False

        if r.status_code == 200 and 'text/html' in r.headers.get('Content-Type', ''):
            soup = BeautifulSoup(r.content, 'html.parser')
            atag_list = soup.find_all('a')
            if first:
                unique_hrefs = []
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                    if href and (href not in unique_hrefs):
                        unique_hrefs.append(href)
                return unique_hrefs
            else:
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                return len(self.master_list)
        else:
            return False

    def get_item_url(self):
        """
        master_list の中から楽天の商品ページURL（例: https://item.rakuten.co.jp/SHOPID/商品ID/）を抽出し、
        self.item_page_list に再格納します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        self.item_page_list = []
        for url in self.master_list:
            if url and re.match(pattern, url):
                self.item_page_list.append(url)
        return self.item_page_list

    def extract_shop_urls(self, existing_shop_ids=None):
        """
        item_page_list の各URLからショップIDを抽出し、
        https://www.rakuten.co.jp/SHOPID/ の形式のショップURLを生成します。
        既存のショップID（existing_shop_ids）に含まれていなければ追加します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        shop_urls = set()
        for item_url in self.item_page_list:
            m = re.match(pattern, item_url)
            if m:
                shop_id = m.group(1)
                shop_url = f"https://www.rakuten.co.jp/{shop_id}/"
                if existing_shop_ids is None or shop_id not in existing_shop_ids:
                    shop_urls.add(shop_url)
        self.shop_url_list = shop_urls
        return list(shop_urls)

def get_company_info_from_info_page(shop_url):
    """
    指定のショップURLに末尾の info.html を付与して企業情報ページにアクセスし、
    <dl> 内の <dt> タグからテキストを取得します。
    そのテキスト内で「株式会社」を含む部分を、余計な情報（〒, TEL, FAX, 代表者, etc.）が出現する直前まで抽出し企業名とします。
    ※「有限会社」が含まれるものは対象外です。
    また、TEL: に続く電話番号も抽出します。
    """
    info_url = shop_url.rstrip('/') + '/info.html'
    print(f"取得する企業情報ページ: {info_url}")
    
    try:
        response = requests.get(info_url, timeout=15)
        response.raise_for_status()
    except Exception as e:
        print("企業情報ページの取得に失敗しました:", e)
        return "Not Found", "Not Found"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    company_name = "Not Found"
    phone_number = "Not Found"
    
    dl_tag = soup.find("dl")
    if dl_tag:
        dt_tags = dl_tag.find_all("dt")
        for dt in dt_tags:
            dt_text = dt.get_text(" ", strip=True)
            if not dt_text:
                continue
            # 正規表現で「株式会社」を含む部分を、〒やTEL等の出現直前まで抽出
            pattern = r'(.*?株式会社.*?)(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
            match = re.search(pattern, dt_text)
            if match:
                company_name = match.group(1).strip()
                break

    tel_elem = soup.find(text=re.compile("TEL:"))
    if tel_elem:
        match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
        if match:
            phone_number = match.group(1)
    
    return company_name, phone_number

def crawl_pagination(scraper, start_url, max_pages=10):
    """
    start_url から始め、最大 max_pages ページまで巡回しながらリンクを収集します。
    HTML内の次ページリンクは、class="item-next nextPage" を持つ <a> タグで取得します。
    """
    current_url = start_url
    pages_crawled = 0
    while current_url and pages_crawled < max_pages:
        print(f"【ページ {pages_crawled+1} をクロール中】 {current_url}")
        # 現在のページのリンクを収集
        scraper.simple_request(current_url, first=True)
        time.sleep(random.uniform(1, 1.5))
        
        try:
            r = requests.get(current_url, timeout=15)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, 'html.parser')
        except Exception as e:
            print("ページ遷移用リンクの取得に失敗:", e)
            break

        # 次ページリンクを class 属性で検索
        next_link = soup.find('a', class_="item-next nextPage")
        if next_link and next_link.get('href'):
            next_url = urljoin(current_url, next_link.get('href'))
            current_url = next_url
            pages_crawled += 1
        else:
            print("次のページが見つかりません。")
            break
    print(f"合計 {pages_crawled} ページをクロールしました。")

if __name__ == "__main__":
    # 既存の企業リスト（ショップURLのみ記載）CSVのファイルパス（相対パス）
    existing_companies_file = "./rakuten_scraping.csv"
    existing_shop_ids = set()
    if os.path.exists(existing_companies_file):
        print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
        with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_url = row.get("shop_url", "").strip()
                shop_id = get_shop_id(shop_url)
                if shop_id:
                    existing_shop_ids.add(shop_id)
        print(f"既存のショップID数: {len(existing_shop_ids)}")
    else:
        print("既存の企業リストが見つかりません。")

    # クロール開始前の入力
    print("例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション")
    while True:
        input_url = input("スクレイピング対象URLを入力してください: ").strip()
        if not input_url.startswith("https://"):
            print("URLが不正です。先頭がhttps:// で始まる必要があります。\n")
            continue
        else:
            print("スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。")
            break

    scraper = RakutenScraper(input_url)
    
    # ページネーションを処理して複数ページからリンクを収集（最大 max_pages ページ）
    max_pages = 2  # 必要に応じて変更
    crawl_pagination(scraper, input_url, max_pages)

    # 収集した全リンクから商品ページURLを抽出
    item_urls = scraper.get_item_url()
    print(f"\n最終的な商品ページURL数: {len(item_urls)}")
    
    # 商品ページURLからショップURL（重複はショップIDでチェック）を抽出
    shop_urls = scraper.extract_shop_urls(existing_shop_ids)
    print(f"取得した新規ショップURLの数: {len(shop_urls)}")

    results = []
    for shop_url in shop_urls:
        info_url = shop_url.rstrip('/') + '/info.html'
        company_name, telephone = get_company_info_from_info_page(shop_url)
        results.append({
            "shop_url": shop_url,
            "info_url": info_url,
            "company_name": company_name,
            "telephone": telephone
        })
        time.sleep(random.uniform(1, 2))
    
    # CSV出力用ディレクトリ作成
    csv_dir = "./csv_data/"
    if not os.path.exists(csv_dir):
        os.makedirs(csv_dir)
    
    filename = f"{today}-company_info.csv"
    output_path = os.path.join(csv_dir, filename)
    
    with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
        fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for row in results:
            writer.writerow(row)
    
    print(f"\n--- CSV出力完了 ---\nファイル: {output_path}")
    
    # 既存リストへの新規ショップURLの追記（ショップIDで重複チェック）
    new_shops = {res["shop_url"] for res in results if get_shop_id(res["shop_url"]) not in existing_shop_ids}
    if new_shops:
        with open(existing_companies_file, 'a', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            for shop in new_shops:
                writer.writerow({"shop_url": shop})
        print(f"\n--- 新規ショップURLを既存企業リストに追加しました ---\nファイル: {existing_companies_file}")
    else:
        print("新しいショップURLは見つかりませんでした。")
    
    print("処理が完了しました。")
# Out:
# 既存の企業リスト ./rakuten_scraping.csv を読み込みます。
# 既存のショップID数: 0
# 例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション
# スクレイピング対象URLを入力してください:  https://search.rakuten.co.jp/search/mall/-/101975/?min=10000
# スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。
# 【ページ 1 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000 | 既存リンク数: 0
# 次のページが見つかりません。
# 合計 0 ページをクロールしました。
#
# 最終的な商品ページURL数: 7
# 取得した新規ショップURLの数: 5
# 取得する企業情報ページ: https://www.rakuten.co.jp/e-kurashi/info.html
# C:\Users\to0ar\AppData\Local\Temp\ipykernel_6584\2179025888.py:134: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tel_elem = soup.find(text=re.compile("TEL:"))
# 取得する企業情報ページ: https://www.rakuten.co.jp/tansu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/unidy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/nuuca/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/esports/info.html
#
# --- CSV出力完了 ---
# ファイル: ./csv_data/2025-03-10-company_info.csv
#
# --- 新規ショップURLを既存企業リストに追加しました ---
# ファイル: ./rakuten_scraping.csv
# 処理が完了しました。

# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import sys
import re
import csv
from urllib.parse import urljoin

today = str(datetime.date.today())

def get_shop_id(shop_url):
    """
    ショップURL（例: https://www.rakuten.co.jp/SHOPID/）からSHOPIDを抽出します。
    """
    pattern = r'^https://www\.rakuten\.co\.jp/([^/]+)/?$'
    m = re.match(pattern, shop_url)
    if m:
        return m.group(1)
    else:
        return None

class RakutenScraper:
    """
    楽天のカテゴリページや検索結果ページから再帰的にリンクを収集し、
    商品ページURLからショップURLを抽出するサンプルクラスです。
    """
    def __init__(self, base_url):
        self.base_url = base_url
        self.master_list = []        # 収集した全リンク
        self.item_page_list = []     # 楽天の商品ページURLのみ
        self.shop_url_list = set()   # 重複排除済みショップURL

    def simple_request(self, url, first=False):
        """
        指定されたURLのページから <a> タグの href を収集し、self.master_list に追加します。
        first=True の場合、初回に取得したリンクリストを返します。
        """
        print(f"アクセス中: {url} | 既存リンク数: {len(self.master_list)}")
        try:
            r = requests.get(url, timeout=(30.0, 47.5))
        except requests.exceptions.RequestException:
            return False

        if r.status_code == 200 and 'text/html' in r.headers.get('Content-Type', ''):
            soup = BeautifulSoup(r.content, 'html.parser')
            atag_list = soup.find_all('a')
            if first:
                unique_hrefs = []
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                    if href and (href not in unique_hrefs):
                        unique_hrefs.append(href)
                return unique_hrefs
            else:
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                return len(self.master_list)
        else:
            return False

    def get_item_url(self):
        """
        master_list の中から楽天の商品ページURL（例: https://item.rakuten.co.jp/SHOPID/商品ID/）を抽出し、
        self.item_page_list に再格納します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        self.item_page_list = []
        for url in self.master_list:
            if url and re.match(pattern, url):
                self.item_page_list.append(url)
        return self.item_page_list

    def extract_shop_urls(self, existing_shop_ids=None):
        """
        item_page_list の各URLからショップIDを抽出し、
        https://www.rakuten.co.jp/SHOPID/ の形式のショップURLを生成します。
        既存のショップID（existing_shop_ids）に含まれていなければ追加します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        shop_urls = set()
        for item_url in self.item_page_list:
            m = re.match(pattern, item_url)
            if m:
                shop_id = m.group(1)
                shop_url = f"https://www.rakuten.co.jp/{shop_id}/"
                if existing_shop_ids is None or shop_id not in existing_shop_ids:
                    shop_urls.add(shop_url)
        self.shop_url_list = shop_urls
        return list(shop_urls)

def get_company_info_from_info_page(shop_url):
    """
    指定のショップURLに末尾の info.html を付与して企業情報ページにアクセスし、
    <dl> 内の <dt> タグからテキストを取得します。
    そのテキスト内で「株式会社」を含む部分を、余計な情報（〒, TEL, FAX, 代表者, etc.）が出現する直前まで抽出し企業名とします。
    ※「有限会社」が含まれるものは対象外です。
    また、TEL: に続く電話番号も抽出します。
    """
    info_url = shop_url.rstrip('/') + '/info.html'
    print(f"取得する企業情報ページ: {info_url}")
    
    try:
        response = requests.get(info_url, timeout=15)
        response.raise_for_status()
    except Exception as e:
        print("企業情報ページの取得に失敗しました:", e)
        return "Not Found", "Not Found"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    company_name = "Not Found"
    phone_number = "Not Found"
    
    dl_tag = soup.find("dl")
    if dl_tag:
        dt_tags = dl_tag.find_all("dt")
        for dt in dt_tags:
            dt_text = dt.get_text(" ", strip=True)
            if not dt_text:
                continue
            # 正規表現で「株式会社」を含む部分を、〒やTEL等が出現する直前まで抽出
            pattern = r'(.*?株式会社.*?)(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
            match = re.search(pattern, dt_text)
            if match:
                company_name = match.group(1).strip()
                break

    tel_elem = soup.find(text=re.compile("TEL:"))
    if tel_elem:
        match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
        if match:
            phone_number = match.group(1)
    
    return company_name, phone_number

def crawl_pagination(scraper, start_url, max_pages=10):
    """
    start_url から始め、最大 max_pages ページまで巡回しながらリンクを収集します。
    HTML内の次ページリンクは、クラスが "item", "-next", "nextPage" を含む <a> タグで取得します。
    """
    current_url = start_url
    pages_crawled = 0
    while current_url and pages_crawled < max_pages:
        print(f"【ページ {pages_crawled+1} をクロール中】 {current_url}")
        # 現在のページのリンクを収集
        scraper.simple_request(current_url, first=True)
        time.sleep(random.uniform(1, 1.5))
        
        try:
            r = requests.get(current_url, timeout=15)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, 'html.parser')
        except Exception as e:
            print("ページ遷移用リンクの取得に失敗:", e)
            break

        # 次ページリンクを CSS セレクターで取得 (クラス: item, -next, nextPage)
        next_link = soup.select_one("a.item.-next.nextPage")
        if next_link and next_link.get('href'):
            next_url = urljoin(current_url, next_link.get('href'))
            current_url = next_url
            pages_crawled += 1
        else:
            print("次のページが見つかりません。")
            break
    print(f"合計 {pages_crawled} ページをクロールしました。")

if __name__ == "__main__":
    # 既存の企業リスト（ショップURLのみ記載）CSVのファイルパス（相対パス）
    existing_companies_file = "./rakuten_scraping.csv"
    existing_shop_ids = set()
    if os.path.exists(existing_companies_file):
        print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
        with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_url = row.get("shop_url", "").strip()
                shop_id = get_shop_id(shop_url)
                if shop_id:
                    existing_shop_ids.add(shop_id)
        print(f"既存のショップID数: {len(existing_shop_ids)}")
    else:
        print("既存の企業リストが見つかりません。")

    print("例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション")
    while True:
        input_url = input("スクレイピング対象URLを入力してください: ").strip()
        if not input_url.startswith("https://"):
            print("URLが不正です。先頭がhttps:// で始まる必要があります。\n")
            continue
        else:
            print("スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。")
            break

    scraper = RakutenScraper(input_url)
    
    # ページネーションを処理して複数ページからリンクを収集（最大 max_pages ページ）
    max_pages = 100  # 必要に応じて変更
    crawl_pagination(scraper, input_url, max_pages)

    # 収集した全リンクから商品ページURLを抽出
    item_urls = scraper.get_item_url()
    print(f"\n最終的な商品ページURL数: {len(item_urls)}")
    
    # 商品ページURLからショップURL（重複はショップIDでチェック）を抽出
    shop_urls = scraper.extract_shop_urls(existing_shop_ids)
    print(f"取得した新規ショップURLの数: {len(shop_urls)}")

    results = []
    for shop_url in shop_urls:
        info_url = shop_url.rstrip('/') + '/info.html'
        company_name, telephone = get_company_info_from_info_page(shop_url)
        results.append({
            "shop_url": shop_url,
            "info_url": info_url,
            "company_name": company_name,
            "telephone": telephone
        })
        time.sleep(random.uniform(1, 2))
    
    # CSV出力用ディレクトリ作成
    csv_dir = "./csv_data/"
    if not os.path.exists(csv_dir):
        os.makedirs(csv_dir)
    
    filename = f"{today}-company_info.csv"
    output_path = os.path.join(csv_dir, filename)
    
    with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
        fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for row in results:
            writer.writerow(row)
    
    print(f"\n--- CSV出力完了 ---\nファイル: {output_path}")
    
    # 既存リストへの新規ショップURLの追記（ショップIDで重複チェック）
    new_shops = {res["shop_url"] for res in results if get_shop_id(res["shop_url"]) not in existing_shop_ids}
    if new_shops:
        with open(existing_companies_file, 'a', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            for shop in new_shops:
                writer.writerow({"shop_url": shop})
        print(f"\n--- 新規ショップURLを既存企業リストに追加しました ---\nファイル: {existing_companies_file}")
    else:
        print("新しいショップURLは見つかりませんでした。")
    
    print("処理が完了しました。")
# Out:
# 既存の企業リスト ./rakuten_scraping.csv を読み込みます。
# 既存のショップID数: 0
# 例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション
# スクレイピング対象URLを入力してください:  https://search.rakuten.co.jp/search/mall/-/101975/?min=10000
# スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。
# 【ページ 1 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000 | 既存リンク数: 0
# 【ページ 2 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=2
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=2 | 既存リンク数: 284
# 【ページ 3 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=3
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=3 | 既存リンク数: 429
# 【ページ 4 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=4
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=4 | 既存リンク数: 561
# 【ページ 5 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=5
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=5 | 既存リンク数: 681
# 【ページ 6 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=6
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=6 | 既存リンク数: 814
# 【ページ 7 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=7
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=7 | 既存リンク数: 925
# 【ページ 8 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=8
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=8 | 既存リンク数: 1106
# 【ページ 9 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=9
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=9 | 既存リンク数: 1227
# 【ページ 10 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=10
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=10 | 既存リンク数: 1345
# 【ページ 11 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=11
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=11 | 既存リンク数: 1468
# 【ページ 12 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=12
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=12 | 既存リンク数: 1597
# 【ページ 13 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=13
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=13 | 既存リンク数: 1707
# 【ページ 14 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=65 | 既存リンク数: 7259
# 【ページ 66 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=66
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=66 | 既存リンク数: 7360
# 【ページ 67 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=67
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=67 | 既存リンク数: 7451
# 【ページ 68 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=68
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=68 | 既存リンク数: 7550
# 【ページ 69 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=69
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=69 | 既存リンク数: 7653
# 【ページ 70 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=70
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=70 | 既存リンク数: 7761
# 【ページ 71 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=71
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=71 | 既存リンク数: 7859
# 【ページ 72 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=72
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=72 | 既存リンク数: 7961
# 【ページ 73 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=73
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=73 | 既存リンク数: 8053
# 【ページ 74 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=74
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=74 | 既存リンク数: 8153
# 【ページ 75 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=75
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=75 | 既存リンク数: 8249
# 【ページ 76 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=76
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=76 | 既存リンク数: 8344
# 【ページ 77 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=77
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=77 | 既存リンク数: 8447
# 【ページ 78 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=78
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=78 | 既存リンク数: 8552
# 【ページ 79 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=79
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=79 | 既存リンク数: 8650
# 【ページ 80 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=80
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=80 | 既存リンク数: 8747
# 【ページ 81 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=81
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=81 | 既存リンク数: 8851
# 【ページ 82 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=82
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=82 | 既存リンク数: 8956
# 【ページ 83 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=83
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=83 | 既存リンク数: 9058
# 【ページ 84 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=84
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=84 | 既存リンク数: 9161
# 【ページ 85 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=85
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=85 | 既存リンク数: 9263
# 【ページ 86 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=86
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=86 | 既存リンク数: 9359
# 【ページ 87 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=87
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=87 | 既存リンク数: 9452
# 【ページ 88 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=88
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=88 | 既存リンク数: 9545
# 【ページ 89 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=89
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=89 | 既存リンク数: 9640
# 【ページ 90 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=90
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=90 | 既存リンク数: 9728
# 【ページ 91 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=91
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=91 | 既存リンク数: 9825
# 【ページ 92 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=92
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=92 | 既存リンク数: 9927
# 【ページ 93 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=93
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=93 | 既存リンク数: 10021
# 【ページ 94 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=94
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=94 | 既存リンク数: 10113
# 【ページ 95 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=95
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=95 | 既存リンク数: 10210
# 【ページ 96 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=96
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=96 | 既存リンク数: 10307
# 【ページ 97 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=97
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=97 | 既存リンク数: 10404
# 【ページ 98 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=98
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=98 | 既存リンク数: 10500
# 【ページ 99 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=99
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=99 | 既存リンク数: 10592
# 【ページ 100 をクロール中】 https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=100
# アクセス中: https://search.rakuten.co.jp/search/mall/-/101975/?min=10000&p=100 | 既存リンク数: 10684
# 合計 100 ページをクロールしました。
#
# 最終的な商品ページURL数: 519
# 取得した新規ショップURLの数: 114
# 取得する企業情報ページ: https://www.rakuten.co.jp/biken-concierge/info.html
# C:\Users\to0ar\AppData\Local\Temp\ipykernel_6584\474183946.py:134: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tel_elem = soup.find(text=re.compile("TEL:"))
# 取得する企業情報ページ: https://www.rakuten.co.jp/himarayaod/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f182010-fukui/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/shop-senjin/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/storage-g/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/plusys7022/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/chamonix/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/euro-surplus/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/esports/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/rococostore/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/g-dreams/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/field-seven/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ninerock/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/workwearlab/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/victorinox/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/twopedal/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/enetroom/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/leatherman-tool-japan/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/k-sumai/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f212105-ena/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/nuuca/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/manpyousyouten0802/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/e-kurashi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f332135-akaiwa/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ease-space/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/lbreath/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f-sommelier/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/captainstagstore/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/flhq/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/victoriagolf/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bruckeoutdoor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f282201-kasai/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/founder/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/store-megasports/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/northfeel-lifestyle/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/fengzel/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hayakawa2021/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/supersportsxebio/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/smartkitchen/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/victoria-online/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/akio/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tansu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/northfeel/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/watermode/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/tomount/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/decathlon-japan/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/workerbee/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f082341-hokota/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/upi-outdoor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/a-price/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hobbytoy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/importshopaqua/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f212113-minokamo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/alpen/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/naturum/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/monoichi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/premium-interior/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sendai-meiban/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/plywoodcamp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/naturum-outdoor/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/demode-keystation/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/passageshop/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/otakaratuuhan/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/toyokuni/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/coody-japan/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kiitos1976/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/himaraya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/rockbros/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kingcamp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f272159-neyagawa/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f252140-maibara/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/marine-mate/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/americana/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f082368-omitama/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/outdoorgear/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/dcmonline/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/flaner/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f212059-seki/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/unidy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/palmy/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/shiroi-taiyaki-group/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/mecu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/stridelab/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/yamatakanamono/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/arimas/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/irisplaza-r/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f152137-tsubame/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/thetent/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/harukaclub/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/baby-days/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f052094-kazuno/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kagustyle/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/qunature/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/abctown/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/saunacamp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/naturum-fashion/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/apolloex/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/auc-roadster/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hilander/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/maxshare/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/fujinami/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/takisyo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/r-tools/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/plywood/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ouchimawari/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/sakaiya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/creak/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kojitu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/hermanherman/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bagshoparr/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/yoshikip2/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ga-living/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/ventlax/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/u-denki/info.html
#
# --- CSV出力完了 ---
# ファイル: ./csv_data/2025-03-10-company_info.csv
#
# --- 新規ショップURLを既存企業リストに追加しました ---
# ファイル: ./rakuten_scraping.csv
# 処理が完了しました。

# %%
import requests
import time
import datetime
import random
from bs4 import BeautifulSoup
import os
import sys
import re
import csv
from urllib.parse import urljoin

today = str(datetime.date.today())

def get_shop_id(shop_url):
    """
    ショップURL（例: https://www.rakuten.co.jp/SHOPID/ または https://www.rakuten.co.jp/gold/SHOPID/）からSHOPIDを抽出します。
    """
    pattern = r'^https://www\.rakuten\.co\.jp/(?:gold/)?([^/]+)/?$'
    m = re.match(pattern, shop_url)
    if m:
        return m.group(1)
    else:
        return None

class RakutenScraper:
    """
    楽天のカテゴリページや検索結果ページから再帰的にリンクを収集し、
    商品ページURLからショップURLを抽出するサンプルクラスです。
    """
    def __init__(self, base_url):
        self.base_url = base_url
        self.master_list = []        # 収集した全リンク
        self.item_page_list = []     # 楽天の商品ページURLのみ
        self.shop_url_list = set()   # 重複排除済みショップURL

    def simple_request(self, url, first=False):
        """
        指定されたURLのページから <a> タグの href を収集し、self.master_list に追加します。
        first=True の場合、初回に取得したリンクリストを返します。
        """
        print(f"アクセス中: {url} | 既存リンク数: {len(self.master_list)}")
        try:
            r = requests.get(url, timeout=(30.0, 47.5))
        except requests.exceptions.RequestException:
            return False

        if r.status_code == 200 and 'text/html' in r.headers.get('Content-Type', ''):
            soup = BeautifulSoup(r.content, 'html.parser')
            atag_list = soup.find_all('a')
            if first:
                unique_hrefs = []
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                    if href and (href not in unique_hrefs):
                        unique_hrefs.append(href)
                return unique_hrefs
            else:
                for a_tag in atag_list:
                    href = a_tag.get('href')
                    if href and (href not in self.master_list):
                        self.master_list.append(href)
                return len(self.master_list)
        else:
            return False

    def get_item_url(self):
        """
        master_list の中から楽天の商品ページURL（例: https://item.rakuten.co.jp/SHOPID/商品ID/）を抽出し、
        self.item_page_list に再格納します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        self.item_page_list = []
        for url in self.master_list:
            if url and re.match(pattern, url):
                self.item_page_list.append(url)
        return self.item_page_list

    def extract_shop_urls(self, existing_shop_ids=None):
        """
        item_page_list の各URLからショップIDを抽出し、
        https://www.rakuten.co.jp/SHOPID/ の形式のショップURLを生成します。
        既存のショップID（existing_shop_ids）に含まれていなければ追加します。
        """
        pattern = r'^https://item\.rakuten\.co\.jp/([^/]+)/(\d+)/?$'
        shop_urls = set()
        for item_url in self.item_page_list:
            m = re.match(pattern, item_url)
            if m:
                shop_id = m.group(1)
                shop_url = f"https://www.rakuten.co.jp/{shop_id}/"
                if existing_shop_ids is None or shop_id not in existing_shop_ids:
                    shop_urls.add(shop_url)
        self.shop_url_list = shop_urls
        return list(shop_urls)

def get_company_info_from_info_page(shop_url):
    """
    指定のショップURLに末尾の info.html を付与して企業情報ページにアクセスし、
    <dl> 内の <dt> タグからテキストを取得します。
    そのテキスト内で「株式会社」を含む部分を、余計な情報（〒, TEL, FAX, 代表者, etc.）が出現する直前まで抽出し企業名とします。
    ※「有限会社」が含まれるものは対象外です。
    また、TEL: に続く電話番号も抽出します。
    """
    info_url = shop_url.rstrip('/') + '/info.html'
    print(f"取得する企業情報ページ: {info_url}")
    
    try:
        response = requests.get(info_url, timeout=15)
        response.raise_for_status()
    except Exception as e:
        print("企業情報ページの取得に失敗しました:", e)
        return "Not Found", "Not Found"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    company_name = "Not Found"
    phone_number = "Not Found"
    
    dl_tag = soup.find("dl")
    if dl_tag:
        dt_tags = dl_tag.find_all("dt")
        for dt in dt_tags:
            dt_text = dt.get_text(" ", strip=True)
            if not dt_text:
                continue
            # 正規表現で「株式会社」を含む部分を、〒やTEL等が出現する直前まで抽出
            pattern = r'(.*?株式会社.*?)(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
            match = re.search(pattern, dt_text)
            if match:
                company_name = match.group(1).strip()
                break

    tel_elem = soup.find(text=re.compile("TEL:"))
    if tel_elem:
        match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
        if match:
            phone_number = match.group(1)
    
    return company_name, phone_number

def crawl_pagination(scraper, start_url, max_pages=10):
    """
    start_url から始め、最大 max_pages ページまで巡回しながらリンクを収集します。
    HTML内の次ページリンクは、クラスが "item", "-next", "nextPage" を含む <a> タグで取得します。
    """
    current_url = start_url
    pages_crawled = 0
    while current_url and pages_crawled < max_pages:
        print(f"【ページ {pages_crawled+1} をクロール中】 {current_url}")
        # 現在のページのリンクを収集
        scraper.simple_request(current_url, first=True)
        time.sleep(random.uniform(1, 1.5))
        
        try:
            r = requests.get(current_url, timeout=15)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, 'html.parser')
        except Exception as e:
            print("ページ遷移用リンクの取得に失敗:", e)
            break

        # 次ページリンクを CSS セレクターで取得 (クラス: item, -next, nextPage)
        next_link = soup.select_one("a.item.-next.nextPage")
        if next_link and next_link.get('href'):
            next_url = urljoin(current_url, next_link.get('href'))
            current_url = next_url
            pages_crawled += 1
        else:
            print("次のページが見つかりません。")
            break
    print(f"合計 {pages_crawled} ページをクロールしました。")

if __name__ == "__main__":
    # 既存の企業リスト（ショップURLのみ記載）CSVのファイルパス（相対パス）
    existing_companies_file = "./rakuten_scraping.csv"
    existing_shop_ids = set()
    if os.path.exists(existing_companies_file):
        print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
        with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                shop_url = row.get("shop_url", "").strip()
                shop_id = get_shop_id(shop_url)
                if shop_id:
                    existing_shop_ids.add(shop_id)
        print(f"既存のショップID数: {len(existing_shop_ids)}")
    else:
        print("既存の企業リストが見つかりません。")

    print("例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション")
    while True:
        input_url = input("スクレイピング対象URLを入力してください: ").strip()
        if not input_url.startswith("https://"):
            print("URLが不正です。先頭がhttps:// で始まる必要があります。\n")
            continue
        else:
            print("スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。")
            break

    scraper = RakutenScraper(input_url)
    
    # ページネーションを処理して複数ページからリンクを収集（最大 max_pages ページ）
    max_pages = 45  # 必要に応じて変更
    crawl_pagination(scraper, input_url, max_pages)

    # 収集した全リンクから商品ページURLを抽出
    item_urls = scraper.get_item_url()
    print(f"\n最終的な商品ページURL数: {len(item_urls)}")
    
    # 商品ページURLからショップURL（重複はショップIDでチェック）を抽出
    shop_urls = scraper.extract_shop_urls(existing_shop_ids)
    print(f"取得した新規ショップURLの数: {len(shop_urls)}")

    results = []
    for shop_url in shop_urls:
        info_url = shop_url.rstrip('/') + '/info.html'
        company_name, telephone = get_company_info_from_info_page(shop_url)
        results.append({
            "shop_url": shop_url,
            "info_url": info_url,
            "company_name": company_name,
            "telephone": telephone
        })
        time.sleep(random.uniform(1, 2))
    
    # CSV出力用ディレクトリ作成
    csv_dir = "./csv_data/"
    if not os.path.exists(csv_dir):
        os.makedirs(csv_dir)
    
    filename = f"{today}-company_info.csv"
    output_path = os.path.join(csv_dir, filename)
    
    with open(output_path, 'w', newline='', encoding='utf-8-sig') as f:
        fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for row in results:
            writer.writerow(row)
    
    print(f"\n--- CSV出力完了 ---\nファイル: {output_path}")
    
    # 既存リストへの新規ショップURLの追記（ショップIDで重複チェック）
    new_shops = {res["shop_url"] for res in results if get_shop_id(res["shop_url"]) not in existing_shop_ids}
    if new_shops:
        with open(existing_companies_file, 'a', newline='', encoding='utf-8-sig') as f:
            writer = csv.DictWriter(f, fieldnames=["shop_url"])
            for shop in new_shops:
                writer.writerow({"shop_url": shop})
        print(f"\n--- 新規ショップURLを既存企業リストに追加しました ---\nファイル: {existing_companies_file}")
    else:
        print("新しいショップURLは見つかりませんでした。")
    
    print("処理が完了しました。")
# Out:
# 既存の企業リスト ./rakuten_scraping.csv を読み込みます。
# 既存のショップID数: 3619
# 例: https://www.rakuten.co.jp/category/110729/ または https://search.rakuten.co.jp/search/mall/レディースファッション
# スクレイピング対象URLを入力してください:  https://search.rakuten.co.jp/search/mall/-/568421/?min=10000
# スクレイピングを開始します。巡回範囲が大きくなる可能性があるのでご注意ください。
# 【ページ 1 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000 | 既存リンク数: 0
# 【ページ 2 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=2
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=2 | 既存リンク数: 406
# 【ページ 3 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=3
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=3 | 既存リンク数: 556
# 【ページ 4 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=4
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=4 | 既存リンク数: 703
# 【ページ 5 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=5
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=5 | 既存リンク数: 848
# 【ページ 6 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=6
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=6 | 既存リンク数: 988
# 【ページ 7 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=7
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=7 | 既存リンク数: 1125
# 【ページ 8 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=8
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=8 | 既存リンク数: 1262
# 【ページ 9 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=9
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=9 | 既存リンク数: 1387
# 【ページ 10 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=10
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=10 | 既存リンク数: 1520
# 【ページ 11 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=11
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=11 | 既存リンク数: 1647
# 【ページ 12 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=12
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=12 | 既存リンク数: 1779
# 【ページ 13 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=13
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=13 | 既存リンク数: 1914
# 【ページ 14 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=14
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=14 | 既存リンク数: 2053
# 【ページ 15 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=15
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=15 | 既存リンク数: 2183
# 【ページ 16 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=16
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=16 | 既存リンク数: 2303
# 【ページ 17 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=17
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=17 | 既存リンク数: 2419
# 【ページ 18 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=18
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=18 | 既存リンク数: 2547
# 【ページ 19 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=19
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=19 | 既存リンク数: 2666
# 【ページ 20 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=20
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=20 | 既存リンク数: 2788
# 【ページ 21 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=21
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=21 | 既存リンク数: 2914
# 【ページ 22 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=22
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=22 | 既存リンク数: 3033
# 【ページ 23 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=23
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=23 | 既存リンク数: 3161
# 【ページ 24 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=24
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=24 | 既存リンク数: 3277
# 【ページ 25 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=25
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=25 | 既存リンク数: 3394
# 【ページ 26 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=26
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=26 | 既存リンク数: 3510
# 【ページ 27 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=27
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=27 | 既存リンク数: 3632
# 【ページ 28 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=28
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=28 | 既存リンク数: 3748
# 【ページ 29 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=29
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=29 | 既存リンク数: 3859
# 【ページ 30 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=30
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=30 | 既存リンク数: 3972
# 【ページ 31 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=31
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=31 | 既存リンク数: 4090
# 【ページ 32 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=32
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=32 | 既存リンク数: 4195
# 【ページ 33 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=33
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=33 | 既存リンク数: 4320
# 【ページ 34 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=34
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=34 | 既存リンク数: 4430
# 【ページ 35 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=35
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=35 | 既存リンク数: 4545
# 【ページ 36 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=36
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=36 | 既存リンク数: 4653
# 【ページ 37 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=37
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=37 | 既存リンク数: 4767
# 【ページ 38 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=38
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=38 | 既存リンク数: 4884
# 【ページ 39 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=39
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=39 | 既存リンク数: 4995
# 【ページ 40 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=40
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=40 | 既存リンク数: 5105
# 【ページ 41 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=41
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=41 | 既存リンク数: 5218
# 【ページ 42 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=42
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=42 | 既存リンク数: 5326
# 【ページ 43 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=43
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=43 | 既存リンク数: 5436
# 【ページ 44 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=44
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=44 | 既存リンク数: 5544
# 【ページ 45 をクロール中】 https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=45
# アクセス中: https://search.rakuten.co.jp/search/mall/-/568421/?min=10000&p=45 | 既存リンク数: 5665
# 合計 45 ページをクロールしました。
#
# 最終的な商品ページURL数: 234
# 取得した新規ショップURLの数: 20
# 取得する企業情報ページ: https://www.rakuten.co.jp/iketeivilla/info.html
# C:\Users\to0ar\AppData\Local\Temp\ipykernel_6584\708723050.py:134: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tel_elem = soup.find(text=re.compile("TEL:"))
# 取得する企業情報ページ: https://www.rakuten.co.jp/f012301-noboribetsu/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/kosaburo/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/side7/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f182052-ono/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/auc-sanjo-tanaka/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/johnblaze/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/zeitakuya/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/coolcat/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/bmp/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/wathz/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f012262-sunagawa/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/deal-design/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/fgkawamura/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/inden/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/galleria-annex/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/business-bugs/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f336238-nagi/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/f143219-samukawa/info.html
# 取得する企業情報ページ: https://www.rakuten.co.jp/andindustry/info.html
#
# --- CSV出力完了 ---
# ファイル: ./csv_data/2025-03-10-company_info.csv
#
# --- 新規ショップURLを既存企業リストに追加しました ---
# ファイル: ./rakuten_scraping.csv
# 処理が完了しました。

# %%
import csv
import os
import re

def get_shop_id(shop_url):
    """
    ショップURL（例: 
      https://www.rakuten.co.jp/SHOPID/ または 
      https://www.rakuten.co.jp/gold/SHOPID/ 
    ）からSHOPIDを抽出します。
    """
    pattern = r'^https://www\.rakuten\.co\.jp/(?:gold/)?([^/]+)/?$'
    m = re.match(pattern, shop_url)
    if m:
        return m.group(1)
    else:
        return None

existing_companies_file = "./rakuten_scraping.csv"

if os.path.exists(existing_companies_file):
    print(f"既存の企業リスト {existing_companies_file} を読み込みます。")
    existing_shop_ids = set()
    with open(existing_companies_file, 'r', encoding='utf-8-sig') as f:
        reader = csv.DictReader(f)
        for row in reader:
            shop_url = row.get("shop_url", "").strip()
            if shop_url:
                shop_id = get_shop_id(shop_url)
                print("ショップURL:", shop_url, "| ショップID:", shop_id)
                if shop_id:
                    existing_shop_ids.add(shop_id)
    print(f"既存のショップID数: {len(existing_shop_ids)}")
else:
    print("既存の企業リストが見つかりません。")
# Out:
# 既存の企業リスト ./rakuten_scraping.csv を読み込みます。
# ショップURL: https://www.rakuten.co.jp/kanko/ | ショップID: kanko
# ショップURL: https://www.rakuten.co.jp/btnc/ | ショップID: btnc
# ショップURL: https://www.rakuten.co.jp/seven2seven/ | ショップID: seven2seven
# ショップURL: https://www.rakuten.co.jp/eclan/ | ショップID: eclan
# ショップURL: https://www.rakuten.co.jp/f012181-akabira/ | ショップID: f012181-akabira
# ショップURL: https://www.rakuten.co.jp/gloopy/ | ショップID: gloopy
# ショップURL: https://www.rakuten.co.jp/vivostyle/ | ショップID: vivostyle
# ショップURL: https://www.rakuten.co.jp/minamistore/ | ショップID: minamistore
# ショップURL: https://www.rakuten.co.jp/angers/ | ショップID: angers
# ショップURL: https://www.rakuten.co.jp/mzspeed-r/ | ショップID: mzspeed-r
# ショップURL: https://www.rakuten.co.jp/enich-agent/ | ショップID: enich-agent
# ショップURL: https://www.rakuten.co.jp/fukusumi/ | ショップID: fukusumi
# ショップURL: https://www.rakuten.co.jp/bianca-rose/ | ショップID: bianca-rose
# ショップURL: https://www.rakuten.co.jp/skyartjapan/ | ショップID: skyartjapan
# ショップURL: https://www.rakuten.co.jp/atrium2019/ | ショップID: atrium2019
# ショップURL: https://www.rakuten.co.jp/f293628-miyake/ | ショップID: f293628-miyake
# ショップURL: https://www.rakuten.co.jp/f292036-yamatokoriyama/ | ショップID: f292036-yamatokoriyama
# ショップURL: https://www.rakuten.co.jp/unveil-bag/ | ショップID: unveil-bag
# ショップURL: https://www.rakuten.co.jp/passageshop/ | ショップID: passageshop
# ショップURL: https://www.rakuten.co.jp/f252085-ritto/ | ショップID: f252085-ritto
# ショップURL: https://www.rakuten.co.jp/f282103-kakogawa/ | ショップID: f282103-kakogawa
# ショップURL: https://www.rakuten.co.jp/f131075-sumida/ | ショップID: f131075-sumida
# ショップURL: https://www.rakuten.co.jp/kyouwa-print/ | ショップID: kyouwa-print
