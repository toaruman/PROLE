# %%
import requests
from bs4 import BeautifulSoup
import csv
import re
import os

# === 設定 ===
FOLDER = "csv_data"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}

# === 最新のCSVファイルを探す ===
csv_files = [f for f in os.listdir(FOLDER) if f.endswith(".csv") and "_with_info" not in f]
if not csv_files:
    raise FileNotFoundError("csv_dataフォルダに元データのCSVが見つかりませんでした")

latest_csv = max(csv_files, key=lambda x: os.path.getmtime(os.path.join(FOLDER, x)))
INPUT_FILE = os.path.join(FOLDER, latest_csv)
OUTPUT_FILE = INPUT_FILE.replace(".csv", "_with_info.csv")

print(f"📄 処理対象ファイル: {INPUT_FILE}")

# === 企業情報抽出関数 ===
def extract_company_info(info_url):
    print(f"🔍 アクセス中: {info_url}")
    try:
        r = requests.get(info_url, headers=HEADERS, timeout=15)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, 'html.parser')

        company_name = "Not Found"
        phone_number = "Not Found"

        dl_tag = soup.find("dl")
        if dl_tag:
            dt_tags = dl_tag.find_all("dt")
            for dt in dt_tags:
                dt_text = dt.get_text(" ", strip=True)
                if not dt_text:
                    continue
                pattern = r'([\s\S]{0,30}株式会社[\s\S]{0,30})(?=〒|TEL:|FAX:|代表者:|店舗運営責任者:|店舗セキュリティ責任者:|購入履歴|$)'
                match = re.search(pattern, dt_text)
                if match:
                    company_name = match.group(1).strip()
                    break

        tel_elem = soup.find(string=re.compile("TEL:"))
        if tel_elem:
            match = re.search(r'TEL:\s*([\d\-]+)', tel_elem)
            if match:
                phone_number = match.group(1)

        return company_name, phone_number
    except Exception as e:
        print(f"❌ 取得失敗: {e}")
        return "Not Found", "Not Found"

# === メイン処理 ===
with open(INPUT_FILE, 'r', encoding='utf-8-sig') as f:
    reader = csv.DictReader(f)
    rows = list(reader)

for row in rows:
    info_url = row.get("info_url")
    if info_url:
        company, tel = extract_company_info(info_url)
        row["company_name"] = company
        row["telephone"] = tel
    else:
        row["company_name"] = "Not Found"
        row["telephone"] = "Not Found"

with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8-sig') as f:
    fieldnames = ["shop_url", "info_url", "company_name", "telephone"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows)

print(f"\n💾 出力完了: {OUTPUT_FILE}")
# Out:
# 📄 処理対象ファイル: csv_data\2025-04-22_05-34-33_company_info.csv
# 🔍 アクセス中: https://www.rakuten.co.jp/rubeeandsapphire/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mignon666/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mountaingoat/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/free-port/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/iloves-new-fit/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fsn1995/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/lonyiabbi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/gubal/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/alice-and-bob-n/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/laair/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/happybox1/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fairy-hama/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/seraph2020/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/soul-k/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ref-fashion/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/gadgery/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rinkastore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/rod-power/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nanzan/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/neutoronica/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/happiness-rk/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mariaju/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/moonlightmoon/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/korina/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/heart-max/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/aqxia2023/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/moresmileshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/sanaka/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jinnee/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/todayfashion/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ikomatrading/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fashion777zakaya/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/backsideoftokyo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/tramonto/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/dogandclothing/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kei-onlineshop2023/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/furure-yurufuwa/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/seikoshosha/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/yokosowear/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/marcsstore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/shop-orange/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/billabongonlinestore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/emonde/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/studioclip/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/astshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nikoand/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/anyfam/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nopnop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/brilliantcolors/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/samuraiz1/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/saieiishobo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/bio-fujisawa/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kyomisayama/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/maru-zakka/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mobilemode/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hawkeye/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/upswing/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/al-vel-generalstore/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/attara-store/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-ffactory/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/relaxsy/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/oga-nico/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/repairfactory/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/awraprotect/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-tatsuya/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/whatnot/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/junction-produce/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/onetimeshop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/crashbox/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/purebliss/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/alpha-h1/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/x-mall/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/pipi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/soleilss/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ofuji/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hyakunote/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/nobuo1/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/ara-networks/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/r-mart-plus/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fukuraikan/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mokuzo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/asukakobo/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/mokuharu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hankomaturi/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/fujicoposhop/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/olevs/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/auc-across-ia/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/kawauso-leather/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/frypay/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/jugemu-gift/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/grande-w/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/elmu/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/wystyle/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/f072117-tamura/info.html
# 🔍 アクセス中: https://www.rakuten.co.jp/hanatakeya/info.html
#
# 💾 出力完了: csv_data\2025-04-22_05-34-33_company_info_with_info.csv
